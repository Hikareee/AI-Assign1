# %%
import pandas as pd
import numpy as np
import sklearn
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from datasets import load_dataset
from datasets import Dataset, DatasetDict

# %%
ds = load_dataset("imagefolder", data_dir = "./DataSet/images/")
ds = ds['train']
# Out:
# Resolving data files:   0%|          | 0/101000 [00:00<?, ?it/s]

# %%
data = ds.train_test_split(test_size=0.15)

# %%
test = {}
image = []
label = []
with open('./DataSet/meta/meta/test.txt', 'r') as file:

    for line in file:
        text = line.strip()
        before, after = text.split("/")
        after = "./DataSet/images/" + before + "/" + after + ".jpg"
        image.append(after)
        label.append(before)
    
    test["image"] = image
    test["label"] = label

test
# Out:
# {'image': ['./DataSet/images/apple_pie/1011328.jpg',
#   './DataSet/images/apple_pie/101251.jpg',
#   './DataSet/images/apple_pie/1034399.jpg',
#   './DataSet/images/apple_pie/103801.jpg',
#   './DataSet/images/apple_pie/1038694.jpg',
#   './DataSet/images/apple_pie/1047447.jpg',
#   './DataSet/images/apple_pie/1068632.jpg',
#   './DataSet/images/apple_pie/110043.jpg',
#   './DataSet/images/apple_pie/1106961.jpg',
#   './DataSet/images/apple_pie/1113017.jpg',
#   './DataSet/images/apple_pie/116705.jpg',
#   './DataSet/images/apple_pie/1167170.jpg',
#   './DataSet/images/apple_pie/1174330.jpg',
#   './DataSet/images/apple_pie/1180600.jpg',
#   './DataSet/images/apple_pie/1235282.jpg',
#   './DataSet/images/apple_pie/1269202.jpg',
#   './DataSet/images/apple_pie/1272958.jpg',
#   './DataSet/images/apple_pie/1284428.jpg',
#   './DataSet/images/apple_pie/1295996.jpg',
#   './DataSet/images/apple_pie/129668.jpg',
#   './DataSet/images/apple_pie/1321400.jpg',
#   './DataSet/images/apple_pie/1327259.jpg',
#   './DataSet/images/apple_pie/1332030.jpg',
#   './DataSet/images/apple_pie/1364847.jpg',
#   './DataSet/images/apple_pie/1375404.jpg',
#   './DataSet/images/apple_pie/1398774.jpg',
#   './DataSet/images/apple_pie/1420999.jpg',
#   './DataSet/images/apple_pie/1429866.jpg',
#   './DataSet/images/apple_pie/1444702.jpg',
#   './DataSet/images/apple_pie/1461580.jpg',
#   './DataSet/images/apple_pie/1469191.jpg',
#   './DataSet/images/apple_pie/1472631.jpg',
#   './DataSet/images/apple_pie/1510125.jpg',
#   './DataSet/images/apple_pie/1510930.jpg',
#   './DataSet/images/apple_pie/1514110.jpg',
#   './DataSet/images/apple_pie/1526484.jpg',
#   './DataSet/images/apple_pie/1578710.jpg',
#   './DataSet/images/apple_pie/1579622.jpg',
#   './DataSet/images/apple_pie/1579774.jpg',
#   './DataSet/images/apple_pie/1617515.jpg',
#   './DataSet/images/apple_pie/1617793.jpg',
#   './DataSet/images/apple_pie/1626685.jpg',
#   './DataSet/images/apple_pie/1629072.jpg',
#   './DataSet/images/apple_pie/1657587.jpg',
#   './DataSet/images/apple_pie/1674492.jpg',
#   './DataSet/images/apple_pie/168971.jpg',
#   './DataSet/images/apple_pie/175848.jpg',
#   './DataSet/images/apple_pie/1771374.jpg',
#   './DataSet/images/apple_pie/1773419.jpg',
#   './DataSet/images/apple_pie/1774036.jpg',
#   './DataSet/images/apple_pie/1815947.jpg',
#   './DataSet/images/apple_pie/1847621.jpg',
#   './DataSet/images/apple_pie/1854241.jpg',
#   './DataSet/images/apple_pie/1878082.jpg',
#   './DataSet/images/apple_pie/1889575.jpg',
#   './DataSet/images/apple_pie/1893663.jpg',
#   './DataSet/images/apple_pie/1899005.jpg',
#   './DataSet/images/apple_pie/1906009.jpg',
#   './DataSet/images/apple_pie/1919827.jpg',
#   './DataSet/images/apple_pie/2034818.jpg',
#   './DataSet/images/apple_pie/2038171.jpg',
#   './DataSet/images/apple_pie/2040919.jpg',
#   './DataSet/images/apple_pie/2074694.jpg',
#   './DataSet/images/apple_pie/2084963.jpg',
#   './DataSet/images/apple_pie/2097980.jpg',
#   './DataSet/images/apple_pie/2109273.jpg',
#   './DataSet/images/apple_pie/2110985.jpg',
#   './DataSet/images/apple_pie/2113478.jpg',
#   './DataSet/images/apple_pie/2114765.jpg',
#   './DataSet/images/apple_pie/2130269.jpg',
#   './DataSet/images/apple_pie/2175701.jpg',
#   './DataSet/images/apple_pie/2189388.jpg',
#   './DataSet/images/apple_pie/2200733.jpg',
#   './DataSet/images/apple_pie/2206034.jpg',
#   './DataSet/images/apple_pie/2206649.jpg',
#   './DataSet/images/apple_pie/2214366.jpg',
#   './DataSet/images/apple_pie/2218771.jpg',
#   './DataSet/images/apple_pie/224383.jpg',
#   './DataSet/images/apple_pie/224785.jpg',
#   './DataSet/images/apple_pie/2254489.jpg',
#   './DataSet/images/apple_pie/2271474.jpg',
#   './DataSet/images/apple_pie/229142.jpg',
#   './DataSet/images/apple_pie/2298195.jpg',
#   './DataSet/images/apple_pie/2304784.jpg',
#   './DataSet/images/apple_pie/2334907.jpg',
#   './DataSet/images/apple_pie/2338398.jpg',
#   './DataSet/images/apple_pie/2368252.jpg',
#   './DataSet/images/apple_pie/2373323.jpg',
#   './DataSet/images/apple_pie/2374771.jpg',
#   './DataSet/images/apple_pie/2380340.jpg',
#   './DataSet/images/apple_pie/2395631.jpg',
#   './DataSet/images/apple_pie/2402925.jpg',
#   './DataSet/images/apple_pie/2407532.jpg',
#   './DataSet/images/apple_pie/2437888.jpg',
#   './DataSet/images/apple_pie/2440054.jpg',
#   './DataSet/images/apple_pie/2445712.jpg',
#   './DataSet/images/apple_pie/2446133.jpg',
#   './DataSet/images/apple_pie/2446500.jpg',
#   './DataSet/images/apple_pie/246113.jpg',
#   './DataSet/images/apple_pie/2477191.jpg',
#   './DataSet/images/apple_pie/2496124.jpg',
#   './DataSet/images/apple_pie/250066.jpg',
#   './DataSet/images/apple_pie/2511157.jpg',
#   './DataSet/images/apple_pie/2517059.jpg',
#   './DataSet/images/apple_pie/2523219.jpg',
#   './DataSet/images/apple_pie/2523928.jpg',
#   './DataSet/images/apple_pie/2553659.jpg',
#   './DataSet/images/apple_pie/2559009.jpg',
#   './DataSet/images/apple_pie/2566460.jpg',
#   './DataSet/images/apple_pie/257377.jpg',
#   './DataSet/images/apple_pie/2576737.jpg',
#   './DataSet/images/apple_pie/2586042.jpg',
#   './DataSet/images/apple_pie/2596943.jpg',
#   './DataSet/images/apple_pie/2601847.jpg',
#   './DataSet/images/apple_pie/2610524.jpg',
#   './DataSet/images/apple_pie/262170.jpg',
#   './DataSet/images/apple_pie/2629959.jpg',
#   './DataSet/images/apple_pie/2637058.jpg',
#   './DataSet/images/apple_pie/2663191.jpg',
#   './DataSet/images/apple_pie/2669146.jpg',
#   './DataSet/images/apple_pie/2673907.jpg',
#   './DataSet/images/apple_pie/2680614.jpg',
#   './DataSet/images/apple_pie/2698889.jpg',
#   './DataSet/images/apple_pie/2737512.jpg',
#   './DataSet/images/apple_pie/2754101.jpg',
#   './DataSet/images/apple_pie/2766011.jpg',
#   './DataSet/images/apple_pie/2766017.jpg',
#   './DataSet/images/apple_pie/2791334.jpg',
#   './DataSet/images/apple_pie/280007.jpg',
#   './DataSet/images/apple_pie/283209.jpg',
#   './DataSet/images/apple_pie/2848506.jpg',
#   './DataSet/images/apple_pie/2878249.jpg',
#   './DataSet/images/apple_pie/2881877.jpg',
#   './DataSet/images/apple_pie/2909139.jpg',
#   './DataSet/images/apple_pie/2911777.jpg',
#   './DataSet/images/apple_pie/2923139.jpg',
#   './DataSet/images/apple_pie/2945592.jpg',
#   './DataSet/images/apple_pie/2948680.jpg',
#   './DataSet/images/apple_pie/296614.jpg',
#   './DataSet/images/apple_pie/2968812.jpg',
#   './DataSet/images/apple_pie/2983047.jpg',
#   './DataSet/images/apple_pie/300660.jpg',
#   './DataSet/images/apple_pie/3027601.jpg',
#   './DataSet/images/apple_pie/3037459.jpg',
#   './DataSet/images/apple_pie/305590.jpg',
#   './DataSet/images/apple_pie/3068872.jpg',
#   './DataSet/images/apple_pie/3108987.jpg',
#   './DataSet/images/apple_pie/3160240.jpg',
#   './DataSet/images/apple_pie/317970.jpg',
#   './DataSet/images/apple_pie/3214268.jpg',
#   './DataSet/images/apple_pie/3217751.jpg',
#   './DataSet/images/apple_pie/3240840.jpg',
#   './DataSet/images/apple_pie/3242509.jpg',
#   './DataSet/images/apple_pie/3243441.jpg',
#   './DataSet/images/apple_pie/3253793.jpg',
#   './DataSet/images/apple_pie/3257241.jpg',
#   './DataSet/images/apple_pie/3267436.jpg',
#   './DataSet/images/apple_pie/3269273.jpg',
#   './DataSet/images/apple_pie/3270291.jpg',
#   './DataSet/images/apple_pie/3275788.jpg',
#   './DataSet/images/apple_pie/3276340.jpg',
#   './DataSet/images/apple_pie/3280206.jpg',
#   './DataSet/images/apple_pie/3299260.jpg',
#   './DataSet/images/apple_pie/3314985.jpg',
#   './DataSet/images/apple_pie/3327221.jpg',
#   './DataSet/images/apple_pie/3330808.jpg',
#   './DataSet/images/apple_pie/3365558.jpg',
#   './DataSet/images/apple_pie/3385074.jpg',
#   './DataSet/images/apple_pie/343461.jpg',
#   './DataSet/images/apple_pie/3440507.jpg',
#   './DataSet/images/apple_pie/3463862.jpg',
#   './DataSet/images/apple_pie/3464305.jpg',
#   './DataSet/images/apple_pie/3466310.jpg',
#   './DataSet/images/apple_pie/3471337.jpg',
#   './DataSet/images/apple_pie/3485833.jpg',
#   './DataSet/images/apple_pie/3497884.jpg',
#   './DataSet/images/apple_pie/3505644.jpg',
#   './DataSet/images/apple_pie/3517723.jpg',
#   './DataSet/images/apple_pie/3521500.jpg',
#   './DataSet/images/apple_pie/3547012.jpg',
#   './DataSet/images/apple_pie/3553736.jpg',
#   './DataSet/images/apple_pie/3555118.jpg',
#   './DataSet/images/apple_pie/3590485.jpg',
#   './DataSet/images/apple_pie/3594610.jpg',
#   './DataSet/images/apple_pie/3603821.jpg',
#   './DataSet/images/apple_pie/362792.jpg',
#   './DataSet/images/apple_pie/3633369.jpg',
#   './DataSet/images/apple_pie/3635782.jpg',
#   './DataSet/images/apple_pie/3639398.jpg',
#   './DataSet/images/apple_pie/3647026.jpg',
#   './DataSet/images/apple_pie/3676725.jpg',
#   './DataSet/images/apple_pie/3676950.jpg',
#   './DataSet/images/apple_pie/3691035.jpg',
#   './DataSet/images/apple_pie/3708762.jpg',
#   './DataSet/images/apple_pie/3720779.jpg',
#   './DataSet/images/apple_pie/3727785.jpg',
#   './DataSet/images/apple_pie/3746599.jpg',
#   './DataSet/images/apple_pie/3779150.jpg',
#   './DataSet/images/apple_pie/3800561.jpg',
#   './DataSet/images/apple_pie/3809728.jpg',
#   './DataSet/images/apple_pie/3825794.jpg',
#   './DataSet/images/apple_pie/3829004.jpg',
#   './DataSet/images/apple_pie/3860485.jpg',
#   './DataSet/images/apple_pie/38795.jpg',
#   './DataSet/images/apple_pie/3915901.jpg',
#   './DataSet/images/apple_pie/403084.jpg',
#   './DataSet/images/apple_pie/406682.jpg',
#   './DataSet/images/apple_pie/407267.jpg',
#   './DataSet/images/apple_pie/416233.jpg',
#   './DataSet/images/apple_pie/418685.jpg',
#   './DataSet/images/apple_pie/438094.jpg',
#   './DataSet/images/apple_pie/440497.jpg',
#   './DataSet/images/apple_pie/451719.jpg',
#   './DataSet/images/apple_pie/455977.jpg',
#   './DataSet/images/apple_pie/466304.jpg',
#   './DataSet/images/apple_pie/484947.jpg',
#   './DataSet/images/apple_pie/486170.jpg',
#   './DataSet/images/apple_pie/495046.jpg',
#   './DataSet/images/apple_pie/507349.jpg',
#   './DataSet/images/apple_pie/532019.jpg',
#   './DataSet/images/apple_pie/532974.jpg',
#   './DataSet/images/apple_pie/590327.jpg',
#   './DataSet/images/apple_pie/646264.jpg',
#   './DataSet/images/apple_pie/661475.jpg',
#   './DataSet/images/apple_pie/668694.jpg',
#   './DataSet/images/apple_pie/688983.jpg',
#   './DataSet/images/apple_pie/693210.jpg',
#   './DataSet/images/apple_pie/727825.jpg',
#   './DataSet/images/apple_pie/801869.jpg',
#   './DataSet/images/apple_pie/807000.jpg',
#   './DataSet/images/apple_pie/812047.jpg',
#   './DataSet/images/apple_pie/827575.jpg',
#   './DataSet/images/apple_pie/829175.jpg',
#   './DataSet/images/apple_pie/829830.jpg',
#   './DataSet/images/apple_pie/829949.jpg',
#   './DataSet/images/apple_pie/83981.jpg',
#   './DataSet/images/apple_pie/861244.jpg',
#   './DataSet/images/apple_pie/867502.jpg',
#   './DataSet/images/apple_pie/879842.jpg',
#   './DataSet/images/apple_pie/884504.jpg',
#   './DataSet/images/apple_pie/885848.jpg',
#   './DataSet/images/apple_pie/886793.jpg',
#   './DataSet/images/apple_pie/904832.jpg',
#   './DataSet/images/apple_pie/908367.jpg',
#   './DataSet/images/apple_pie/963140.jpg',
#   './DataSet/images/apple_pie/981895.jpg',
#   './DataSet/images/apple_pie/984571.jpg',
#   './DataSet/images/apple_pie/986844.jpg',
#   './DataSet/images/apple_pie/99556.jpg',
#   './DataSet/images/apple_pie/997950.jpg',
#   './DataSet/images/baby_back_ribs/1005066.jpg',
#   './DataSet/images/baby_back_ribs/1022479.jpg',
#   './DataSet/images/baby_back_ribs/1058654.jpg',
#   './DataSet/images/baby_back_ribs/1074480.jpg',
#   './DataSet/images/baby_back_ribs/1086617.jpg',
#   './DataSet/images/baby_back_ribs/1098606.jpg',
#   './DataSet/images/baby_back_ribs/112142.jpg',
#   './DataSet/images/baby_back_ribs/1138370.jpg',
#   './DataSet/images/baby_back_ribs/1145041.jpg',
#   './DataSet/images/baby_back_ribs/1150028.jpg',
#   './DataSet/images/baby_back_ribs/1150070.jpg',
#   './DataSet/images/baby_back_ribs/1183551.jpg',
#   './DataSet/images/baby_back_ribs/1185016.jpg',
#   './DataSet/images/baby_back_ribs/120576.jpg',
#   './DataSet/images/baby_back_ribs/1211064.jpg',
#   './DataSet/images/baby_back_ribs/1221409.jpg',
#   './DataSet/images/baby_back_ribs/1228072.jpg',
#   './DataSet/images/baby_back_ribs/1262675.jpg',
#   './DataSet/images/baby_back_ribs/1285825.jpg',
#   './DataSet/images/baby_back_ribs/1329841.jpg',
#   './DataSet/images/baby_back_ribs/1330649.jpg',
#   './DataSet/images/baby_back_ribs/1339637.jpg',
#   './DataSet/images/baby_back_ribs/1341719.jpg',
#   './DataSet/images/baby_back_ribs/1347489.jpg',
#   './DataSet/images/baby_back_ribs/1352978.jpg',
#   './DataSet/images/baby_back_ribs/1381124.jpg',
#   './DataSet/images/baby_back_ribs/139044.jpg',
#   './DataSet/images/baby_back_ribs/1394367.jpg',
#   './DataSet/images/baby_back_ribs/1395662.jpg',
#   './DataSet/images/baby_back_ribs/1421097.jpg',
#   './DataSet/images/baby_back_ribs/1427390.jpg',
#   './DataSet/images/baby_back_ribs/143583.jpg',
#   './DataSet/images/baby_back_ribs/1451628.jpg',
#   './DataSet/images/baby_back_ribs/1495381.jpg',
#   './DataSet/images/baby_back_ribs/1506362.jpg',
#   './DataSet/images/baby_back_ribs/1512537.jpg',
#   './DataSet/images/baby_back_ribs/1521817.jpg',
#   './DataSet/images/baby_back_ribs/1556943.jpg',
#   './DataSet/images/baby_back_ribs/1573043.jpg',
#   './DataSet/images/baby_back_ribs/1584068.jpg',
#   './DataSet/images/baby_back_ribs/1593880.jpg',
#   './DataSet/images/baby_back_ribs/160194.jpg',
#   './DataSet/images/baby_back_ribs/1622817.jpg',
#   './DataSet/images/baby_back_ribs/1623333.jpg',
#   './DataSet/images/baby_back_ribs/1631249.jpg',
#   './DataSet/images/baby_back_ribs/163622.jpg',
#   './DataSet/images/baby_back_ribs/1636617.jpg',
#   './DataSet/images/baby_back_ribs/1641429.jpg',
#   './DataSet/images/baby_back_ribs/1667679.jpg',
#   './DataSet/images/baby_back_ribs/1678943.jpg',
#   './DataSet/images/baby_back_ribs/1682911.jpg',
#   './DataSet/images/baby_back_ribs/1698180.jpg',
#   './DataSet/images/baby_back_ribs/1732271.jpg',
#   './DataSet/images/baby_back_ribs/1735046.jpg',
#   './DataSet/images/baby_back_ribs/1763693.jpg',
#   './DataSet/images/baby_back_ribs/1765250.jpg',
#   './DataSet/images/baby_back_ribs/1793347.jpg',
#   './DataSet/images/baby_back_ribs/1811267.jpg',
#   './DataSet/images/baby_back_ribs/1833421.jpg',
#   './DataSet/images/baby_back_ribs/1851892.jpg',
#   './DataSet/images/baby_back_ribs/1856264.jpg',
#   './DataSet/images/baby_back_ribs/18596.jpg',
#   './DataSet/images/baby_back_ribs/1873449.jpg',
#   './DataSet/images/baby_back_ribs/1907138.jpg',
#   './DataSet/images/baby_back_ribs/19325.jpg',
#   './DataSet/images/baby_back_ribs/1942524.jpg',
#   './DataSet/images/baby_back_ribs/1943655.jpg',
#   './DataSet/images/baby_back_ribs/1964783.jpg',
#   './DataSet/images/baby_back_ribs/1967177.jpg',
#   './DataSet/images/baby_back_ribs/1995647.jpg',
#   './DataSet/images/baby_back_ribs/2006268.jpg',
#   './DataSet/images/baby_back_ribs/2023403.jpg',
#   './DataSet/images/baby_back_ribs/2025526.jpg',
#   './DataSet/images/baby_back_ribs/2032061.jpg',
#   './DataSet/images/baby_back_ribs/2042437.jpg',
#   './DataSet/images/baby_back_ribs/2053235.jpg',
#   './DataSet/images/baby_back_ribs/2066688.jpg',
#   './DataSet/images/baby_back_ribs/2066952.jpg',
#   './DataSet/images/baby_back_ribs/2079486.jpg',
#   './DataSet/images/baby_back_ribs/2079924.jpg',
#   './DataSet/images/baby_back_ribs/2103750.jpg',
#   './DataSet/images/baby_back_ribs/211120.jpg',
#   './DataSet/images/baby_back_ribs/2129884.jpg',
#   './DataSet/images/baby_back_ribs/2130114.jpg',
#   './DataSet/images/baby_back_ribs/2132277.jpg',
#   './DataSet/images/baby_back_ribs/2134746.jpg',
#   './DataSet/images/baby_back_ribs/2141995.jpg',
#   './DataSet/images/baby_back_ribs/2145496.jpg',
#   './DataSet/images/baby_back_ribs/2185492.jpg',
#   './DataSet/images/baby_back_ribs/2189077.jpg',
#   './DataSet/images/baby_back_ribs/2203767.jpg',
#   './DataSet/images/baby_back_ribs/2213109.jpg',
#   './DataSet/images/baby_back_ribs/2232942.jpg',
#   './DataSet/images/baby_back_ribs/2245405.jpg',
#   './DataSet/images/baby_back_ribs/2252638.jpg',
#   './DataSet/images/baby_back_ribs/2261491.jpg',
#   './DataSet/images/baby_back_ribs/2272205.jpg',
#   './DataSet/images/baby_back_ribs/2275499.jpg',
#   './DataSet/images/baby_back_ribs/2306008.jpg',
#   './DataSet/images/baby_back_ribs/2309590.jpg',
#   './DataSet/images/baby_back_ribs/2314472.jpg',
#   './DataSet/images/baby_back_ribs/2320542.jpg',
#   './DataSet/images/baby_back_ribs/2326074.jpg',
#   './DataSet/images/baby_back_ribs/2331746.jpg',
#   './DataSet/images/baby_back_ribs/2345176.jpg',
#   './DataSet/images/baby_back_ribs/2348457.jpg',
#   './DataSet/images/baby_back_ribs/2349904.jpg',
#   './DataSet/images/baby_back_ribs/2352033.jpg',
#   './DataSet/images/baby_back_ribs/2370716.jpg',
#   './DataSet/images/baby_back_ribs/2407847.jpg',
#   './DataSet/images/baby_back_ribs/2432.jpg',
#   './DataSet/images/baby_back_ribs/2437890.jpg',
#   './DataSet/images/baby_back_ribs/2454123.jpg',
#   './DataSet/images/baby_back_ribs/2464308.jpg',
#   './DataSet/images/baby_back_ribs/2490676.jpg',
#   './DataSet/images/baby_back_ribs/2502288.jpg',
#   './DataSet/images/baby_back_ribs/2517831.jpg',
#   './DataSet/images/baby_back_ribs/2535607.jpg',
#   './DataSet/images/baby_back_ribs/2576256.jpg',
#   './DataSet/images/baby_back_ribs/2587414.jpg',
#   './DataSet/images/baby_back_ribs/2587676.jpg',
#   './DataSet/images/baby_back_ribs/2591611.jpg',
#   './DataSet/images/baby_back_ribs/2602664.jpg',
#   './DataSet/images/baby_back_ribs/2604946.jpg',
#   './DataSet/images/baby_back_ribs/261900.jpg',
#   './DataSet/images/baby_back_ribs/2619132.jpg',
#   './DataSet/images/baby_back_ribs/2624343.jpg',
#   './DataSet/images/baby_back_ribs/2633796.jpg',
#   './DataSet/images/baby_back_ribs/2640078.jpg',
#   './DataSet/images/baby_back_ribs/26834.jpg',
#   './DataSet/images/baby_back_ribs/2687000.jpg',
#   './DataSet/images/baby_back_ribs/269885.jpg',
#   './DataSet/images/baby_back_ribs/2702542.jpg',
#   './DataSet/images/baby_back_ribs/2709715.jpg',
#   './DataSet/images/baby_back_ribs/2710948.jpg',
#   './DataSet/images/baby_back_ribs/2733895.jpg',
#   './DataSet/images/baby_back_ribs/2740626.jpg',
#   './DataSet/images/baby_back_ribs/2764727.jpg',
#   './DataSet/images/baby_back_ribs/2780701.jpg',
#   './DataSet/images/baby_back_ribs/2816200.jpg',
#   './DataSet/images/baby_back_ribs/2823429.jpg',
#   './DataSet/images/baby_back_ribs/2828232.jpg',
#   './DataSet/images/baby_back_ribs/2846282.jpg',
#   './DataSet/images/baby_back_ribs/2854197.jpg',
#   './DataSet/images/baby_back_ribs/286189.jpg',
#   './DataSet/images/baby_back_ribs/2874924.jpg',
#   './DataSet/images/baby_back_ribs/2886780.jpg',
#   './DataSet/images/baby_back_ribs/2897079.jpg',
#   './DataSet/images/baby_back_ribs/2901249.jpg',
#   './DataSet/images/baby_back_ribs/2952510.jpg',
#   './DataSet/images/baby_back_ribs/2954986.jpg',
#   './DataSet/images/baby_back_ribs/2977633.jpg',
#   './DataSet/images/baby_back_ribs/2989382.jpg',
#   './DataSet/images/baby_back_ribs/2992299.jpg',
#   './DataSet/images/baby_back_ribs/3052734.jpg',
#   './DataSet/images/baby_back_ribs/3057918.jpg',
#   './DataSet/images/baby_back_ribs/3069665.jpg',
#   './DataSet/images/baby_back_ribs/3085976.jpg',
#   './DataSet/images/baby_back_ribs/312370.jpg',
#   './DataSet/images/baby_back_ribs/3142180.jpg',
#   './DataSet/images/baby_back_ribs/314812.jpg',
#   './DataSet/images/baby_back_ribs/3222671.jpg',
#   './DataSet/images/baby_back_ribs/3228576.jpg',
#   './DataSet/images/baby_back_ribs/3244661.jpg',
#   './DataSet/images/baby_back_ribs/3256657.jpg',
#   './DataSet/images/baby_back_ribs/3325494.jpg',
#   './DataSet/images/baby_back_ribs/3348957.jpg',
#   './DataSet/images/baby_back_ribs/3367846.jpg',
#   './DataSet/images/baby_back_ribs/3380363.jpg',
#   './DataSet/images/baby_back_ribs/3400201.jpg',
#   './DataSet/images/baby_back_ribs/3412219.jpg',
#   './DataSet/images/baby_back_ribs/3439326.jpg',
#   './DataSet/images/baby_back_ribs/3440392.jpg',
#   './DataSet/images/baby_back_ribs/3446846.jpg',
#   './DataSet/images/baby_back_ribs/3489481.jpg',
#   './DataSet/images/baby_back_ribs/3516733.jpg',
#   './DataSet/images/baby_back_ribs/353489.jpg',
#   './DataSet/images/baby_back_ribs/3575404.jpg',
#   './DataSet/images/baby_back_ribs/3581600.jpg',
#   './DataSet/images/baby_back_ribs/360664.jpg',
#   './DataSet/images/baby_back_ribs/3608011.jpg',
#   './DataSet/images/baby_back_ribs/3619041.jpg',
#   './DataSet/images/baby_back_ribs/3621492.jpg',
#   './DataSet/images/baby_back_ribs/3660437.jpg',
#   './DataSet/images/baby_back_ribs/3664510.jpg',
#   './DataSet/images/baby_back_ribs/3678273.jpg',
#   './DataSet/images/baby_back_ribs/3679934.jpg',
#   './DataSet/images/baby_back_ribs/3680520.jpg',
#   './DataSet/images/baby_back_ribs/3700896.jpg',
#   './DataSet/images/baby_back_ribs/3737603.jpg',
#   './DataSet/images/baby_back_ribs/3748156.jpg',
#   './DataSet/images/baby_back_ribs/3780980.jpg',
#   './DataSet/images/baby_back_ribs/381199.jpg',
#   './DataSet/images/baby_back_ribs/3824491.jpg',
#   './DataSet/images/baby_back_ribs/3828218.jpg',
#   './DataSet/images/baby_back_ribs/384960.jpg',
#   './DataSet/images/baby_back_ribs/3863637.jpg',
#   './DataSet/images/baby_back_ribs/3873682.jpg',
#   './DataSet/images/baby_back_ribs/3887363.jpg',
#   './DataSet/images/baby_back_ribs/3890499.jpg',
#   './DataSet/images/baby_back_ribs/408666.jpg',
#   './DataSet/images/baby_back_ribs/426980.jpg',
#   './DataSet/images/baby_back_ribs/464659.jpg',
#   './DataSet/images/baby_back_ribs/470646.jpg',
#   './DataSet/images/baby_back_ribs/501334.jpg',
#   './DataSet/images/baby_back_ribs/519489.jpg',
#   './DataSet/images/baby_back_ribs/54203.jpg',
#   './DataSet/images/baby_back_ribs/543585.jpg',
#   './DataSet/images/baby_back_ribs/546242.jpg',
#   './DataSet/images/baby_back_ribs/563715.jpg',
#   './DataSet/images/baby_back_ribs/575222.jpg',
#   './DataSet/images/baby_back_ribs/586642.jpg',
#   './DataSet/images/baby_back_ribs/593493.jpg',
#   './DataSet/images/baby_back_ribs/611849.jpg',
#   './DataSet/images/baby_back_ribs/620997.jpg',
#   './DataSet/images/baby_back_ribs/626550.jpg',
#   './DataSet/images/baby_back_ribs/649840.jpg',
#   './DataSet/images/baby_back_ribs/652170.jpg',
#   './DataSet/images/baby_back_ribs/664114.jpg',
#   './DataSet/images/baby_back_ribs/668551.jpg',
#   './DataSet/images/baby_back_ribs/669669.jpg',
#   './DataSet/images/baby_back_ribs/677088.jpg',
#   './DataSet/images/baby_back_ribs/689859.jpg',
#   './DataSet/images/baby_back_ribs/707137.jpg',
#   './DataSet/images/baby_back_ribs/716804.jpg',
#   './DataSet/images/baby_back_ribs/736982.jpg',
#   './DataSet/images/baby_back_ribs/748033.jpg',
#   './DataSet/images/baby_back_ribs/759979.jpg',
#   './DataSet/images/baby_back_ribs/760126.jpg',
#   './DataSet/images/baby_back_ribs/776819.jpg',
#   './DataSet/images/baby_back_ribs/777636.jpg',
#   './DataSet/images/baby_back_ribs/787250.jpg',
#   './DataSet/images/baby_back_ribs/824318.jpg',
#   './DataSet/images/baby_back_ribs/82439.jpg',
#   './DataSet/images/baby_back_ribs/833244.jpg',
#   './DataSet/images/baby_back_ribs/836913.jpg',
#   './DataSet/images/baby_back_ribs/87031.jpg',
#   './DataSet/images/baby_back_ribs/898761.jpg',
#   './DataSet/images/baby_back_ribs/910021.jpg',
#   './DataSet/images/baby_back_ribs/915852.jpg',
#   './DataSet/images/baby_back_ribs/917430.jpg',
#   './DataSet/images/baby_back_ribs/919073.jpg',
#   './DataSet/images/baby_back_ribs/924529.jpg',
#   './DataSet/images/baby_back_ribs/934716.jpg',
#   './DataSet/images/baby_back_ribs/941128.jpg',
#   './DataSet/images/baby_back_ribs/941715.jpg',
#   './DataSet/images/baby_back_ribs/968229.jpg',
#   './DataSet/images/baby_back_ribs/974195.jpg',
#   './DataSet/images/baby_back_ribs/976284.jpg',
#   './DataSet/images/baby_back_ribs/994232.jpg',
#   './DataSet/images/baklava/1028777.jpg',
#   './DataSet/images/baklava/1029051.jpg',
#   './DataSet/images/baklava/104446.jpg',
#   './DataSet/images/baklava/1062541.jpg',
#   './DataSet/images/baklava/1067270.jpg',
#   './DataSet/images/baklava/1075871.jpg',
#   './DataSet/images/baklava/107830.jpg',
#   './DataSet/images/baklava/1110172.jpg',
#   './DataSet/images/baklava/1118803.jpg',
#   './DataSet/images/baklava/1138123.jpg',
#   './DataSet/images/baklava/1150170.jpg',
#   './DataSet/images/baklava/1196728.jpg',
#   './DataSet/images/baklava/120691.jpg',
#   './DataSet/images/baklava/1208747.jpg',
#   './DataSet/images/baklava/1241477.jpg',
#   './DataSet/images/baklava/125912.jpg',
#   './DataSet/images/baklava/1264253.jpg',
#   './DataSet/images/baklava/1266641.jpg',
#   './DataSet/images/baklava/1281439.jpg',
#   './DataSet/images/baklava/1284897.jpg',
#   './DataSet/images/baklava/1292647.jpg',
#   './DataSet/images/baklava/129478.jpg',
#   './DataSet/images/baklava/1297412.jpg',
#   './DataSet/images/baklava/130220.jpg',
#   './DataSet/images/baklava/1310031.jpg',
#   './DataSet/images/baklava/1317164.jpg',
#   './DataSet/images/baklava/1326926.jpg',
#   './DataSet/images/baklava/1336971.jpg',
#   './DataSet/images/baklava/1351482.jpg',
#   './DataSet/images/baklava/1363613.jpg',
#   './DataSet/images/baklava/1389963.jpg',
#   './DataSet/images/baklava/1390709.jpg',
#   './DataSet/images/baklava/1391742.jpg',
#   './DataSet/images/baklava/1392219.jpg',
#   './DataSet/images/baklava/1417138.jpg',
#   './DataSet/images/baklava/143372.jpg',
#   './DataSet/images/baklava/1448425.jpg',
#   './DataSet/images/baklava/1488283.jpg',
#   './DataSet/images/baklava/1502186.jpg',
#   './DataSet/images/baklava/1503293.jpg',
#   './DataSet/images/baklava/1513651.jpg',
#   './DataSet/images/baklava/1520628.jpg',
#   './DataSet/images/baklava/1540948.jpg',
#   './DataSet/images/baklava/1547455.jpg',
#   './DataSet/images/baklava/1547472.jpg',
#   './DataSet/images/baklava/1550074.jpg',
#   './DataSet/images/baklava/155221.jpg',
#   './DataSet/images/baklava/158510.jpg',
#   './DataSet/images/baklava/1600317.jpg',
#   './DataSet/images/baklava/1601530.jpg',
#   './DataSet/images/baklava/1648719.jpg',
#   './DataSet/images/baklava/1687299.jpg',
#   './DataSet/images/baklava/1705577.jpg',
#   './DataSet/images/baklava/1709269.jpg',
#   './DataSet/images/baklava/1717840.jpg',
#   './DataSet/images/baklava/1720866.jpg',
#   './DataSet/images/baklava/1739946.jpg',
#   './DataSet/images/baklava/1746317.jpg',
#   './DataSet/images/baklava/1758057.jpg',
#   './DataSet/images/baklava/1762550.jpg',
#   './DataSet/images/baklava/1772994.jpg',
#   './DataSet/images/baklava/1795930.jpg',
#   './DataSet/images/baklava/1823708.jpg',
#   './DataSet/images/baklava/1834720.jpg',
#   './DataSet/images/baklava/1846365.jpg',
#   './DataSet/images/baklava/1849718.jpg',
#   './DataSet/images/baklava/1881388.jpg',
#   './DataSet/images/baklava/1885421.jpg',
#   './DataSet/images/baklava/1896759.jpg',
#   './DataSet/images/baklava/1915978.jpg',
#   './DataSet/images/baklava/1946286.jpg',
#   './DataSet/images/baklava/1988719.jpg',
#   './DataSet/images/baklava/2021629.jpg',
#   './DataSet/images/baklava/2028827.jpg',
#   './DataSet/images/baklava/2041299.jpg',
#   './DataSet/images/baklava/2068554.jpg',
#   './DataSet/images/baklava/206902.jpg',
#   './DataSet/images/baklava/2073284.jpg',
#   './DataSet/images/baklava/209463.jpg',
#   './DataSet/images/baklava/2102830.jpg',
#   './DataSet/images/baklava/2106469.jpg',
#   './DataSet/images/baklava/2117032.jpg',
#   './DataSet/images/baklava/2148215.jpg',
#   './DataSet/images/baklava/2156244.jpg',
#   './DataSet/images/baklava/2162852.jpg',
#   './DataSet/images/baklava/2171197.jpg',
#   './DataSet/images/baklava/2186251.jpg',
#   './DataSet/images/baklava/2278334.jpg',
#   './DataSet/images/baklava/2284086.jpg',
#   './DataSet/images/baklava/2284673.jpg',
#   './DataSet/images/baklava/2309578.jpg',
#   './DataSet/images/baklava/2313082.jpg',
#   './DataSet/images/baklava/2321560.jpg',
#   './DataSet/images/baklava/2322552.jpg',
#   './DataSet/images/baklava/2348370.jpg',
#   './DataSet/images/baklava/2373207.jpg',
#   './DataSet/images/baklava/2374859.jpg',
#   './DataSet/images/baklava/2379083.jpg',
#   './DataSet/images/baklava/2412675.jpg',
#   './DataSet/images/baklava/2433084.jpg',
#   './DataSet/images/baklava/2444054.jpg',
#   './DataSet/images/baklava/2446068.jpg',
#   './DataSet/images/baklava/2447796.jpg',
#   './DataSet/images/baklava/2465433.jpg',
#   './DataSet/images/baklava/2481609.jpg',
#   './DataSet/images/baklava/2487865.jpg',
#   './DataSet/images/baklava/2511087.jpg',
#   './DataSet/images/baklava/2532310.jpg',
#   './DataSet/images/baklava/2539615.jpg',
#   './DataSet/images/baklava/2542430.jpg',
#   './DataSet/images/baklava/2546811.jpg',
#   './DataSet/images/baklava/2553456.jpg',
#   './DataSet/images/baklava/2555804.jpg',
#   './DataSet/images/baklava/2556193.jpg',
#   './DataSet/images/baklava/2566349.jpg',
#   './DataSet/images/baklava/2569979.jpg',
#   './DataSet/images/baklava/2573536.jpg',
#   './DataSet/images/baklava/2582738.jpg',
#   './DataSet/images/baklava/2593821.jpg',
#   './DataSet/images/baklava/2644083.jpg',
#   './DataSet/images/baklava/2649603.jpg',
#   './DataSet/images/baklava/2662831.jpg',
#   './DataSet/images/baklava/2683612.jpg',
#   './DataSet/images/baklava/2692458.jpg',
#   './DataSet/images/baklava/2694279.jpg',
#   './DataSet/images/baklava/2708501.jpg',
#   './DataSet/images/baklava/2718099.jpg',
#   './DataSet/images/baklava/2751965.jpg',
#   './DataSet/images/baklava/2768985.jpg',
#   './DataSet/images/baklava/2828700.jpg',
#   './DataSet/images/baklava/2841494.jpg',
#   './DataSet/images/baklava/285000.jpg',
#   './DataSet/images/baklava/2860627.jpg',
#   './DataSet/images/baklava/28613.jpg',
#   './DataSet/images/baklava/2924742.jpg',
#   './DataSet/images/baklava/2925079.jpg',
#   './DataSet/images/baklava/2946891.jpg',
#   './DataSet/images/baklava/295046.jpg',
#   './DataSet/images/baklava/295863.jpg',
#   './DataSet/images/baklava/3006203.jpg',
#   './DataSet/images/baklava/3009508.jpg',
#   './DataSet/images/baklava/3044167.jpg',
#   './DataSet/images/baklava/3050269.jpg',
#   './DataSet/images/baklava/3055850.jpg',
#   './DataSet/images/baklava/3061534.jpg',
#   './DataSet/images/baklava/3067354.jpg',
#   './DataSet/images/baklava/3074769.jpg',
#   './DataSet/images/baklava/3078639.jpg',
#   './DataSet/images/baklava/3085734.jpg',
#   './DataSet/images/baklava/3112621.jpg',
#   './DataSet/images/baklava/3117752.jpg',
#   './DataSet/images/baklava/3124550.jpg',
#   './DataSet/images/baklava/3136582.jpg',
#   './DataSet/images/baklava/3158779.jpg',
#   './DataSet/images/baklava/3158786.jpg',
#   './DataSet/images/baklava/3213763.jpg',
#   './DataSet/images/baklava/3276903.jpg',
#   './DataSet/images/baklava/3278527.jpg',
#   './DataSet/images/baklava/3297561.jpg',
#   './DataSet/images/baklava/3297567.jpg',
#   './DataSet/images/baklava/3311502.jpg',
#   './DataSet/images/baklava/332407.jpg',
#   './DataSet/images/baklava/3340929.jpg',
#   './DataSet/images/baklava/335538.jpg',
#   './DataSet/images/baklava/3358883.jpg',
#   './DataSet/images/baklava/3363499.jpg',
#   './DataSet/images/baklava/3368791.jpg',
#   './DataSet/images/baklava/3369406.jpg',
#   './DataSet/images/baklava/3391092.jpg',
#   './DataSet/images/baklava/3391167.jpg',
#   './DataSet/images/baklava/343124.jpg',
#   './DataSet/images/baklava/3444445.jpg',
#   './DataSet/images/baklava/3452248.jpg',
#   './DataSet/images/baklava/3453153.jpg',
#   './DataSet/images/baklava/3455436.jpg',
#   './DataSet/images/baklava/3468496.jpg',
#   './DataSet/images/baklava/3477977.jpg',
#   './DataSet/images/baklava/3480784.jpg',
#   './DataSet/images/baklava/3482045.jpg',
#   './DataSet/images/baklava/349456.jpg',
#   './DataSet/images/baklava/3496527.jpg',
#   './DataSet/images/baklava/3498449.jpg',
#   './DataSet/images/baklava/3517946.jpg',
#   './DataSet/images/baklava/3528628.jpg',
#   './DataSet/images/baklava/3556892.jpg',
#   './DataSet/images/baklava/356890.jpg',
#   './DataSet/images/baklava/3570121.jpg',
#   './DataSet/images/baklava/3578527.jpg',
#   './DataSet/images/baklava/3584585.jpg',
#   './DataSet/images/baklava/3608369.jpg',
#   './DataSet/images/baklava/3628916.jpg',
#   './DataSet/images/baklava/3645013.jpg',
#   './DataSet/images/baklava/3655808.jpg',
#   './DataSet/images/baklava/3669911.jpg',
#   './DataSet/images/baklava/3680783.jpg',
#   './DataSet/images/baklava/3696940.jpg',
#   './DataSet/images/baklava/3697640.jpg',
#   './DataSet/images/baklava/370124.jpg',
#   './DataSet/images/baklava/3734372.jpg',
#   './DataSet/images/baklava/3745075.jpg',
#   './DataSet/images/baklava/3753309.jpg',
#   './DataSet/images/baklava/3765756.jpg',
#   './DataSet/images/baklava/3768887.jpg',
#   './DataSet/images/baklava/3769622.jpg',
#   './DataSet/images/baklava/3780885.jpg',
#   './DataSet/images/baklava/3782828.jpg',
#   './DataSet/images/baklava/3785055.jpg',
#   './DataSet/images/baklava/3797211.jpg',
#   './DataSet/images/baklava/3801543.jpg',
#   './DataSet/images/baklava/3885250.jpg',
#   './DataSet/images/baklava/3889053.jpg',
#   './DataSet/images/baklava/3893932.jpg',
#   './DataSet/images/baklava/461467.jpg',
#   './DataSet/images/baklava/473273.jpg',
#   './DataSet/images/baklava/490206.jpg',
#   './DataSet/images/baklava/50627.jpg',
#   './DataSet/images/baklava/506922.jpg',
#   './DataSet/images/baklava/521925.jpg',
#   './DataSet/images/baklava/558342.jpg',
#   './DataSet/images/baklava/563537.jpg',
#   './DataSet/images/baklava/567973.jpg',
#   './DataSet/images/baklava/613574.jpg',
#   './DataSet/images/baklava/640052.jpg',
#   './DataSet/images/baklava/6789.jpg',
#   './DataSet/images/baklava/689207.jpg',
#   './DataSet/images/baklava/694258.jpg',
#   './DataSet/images/baklava/704086.jpg',
#   './DataSet/images/baklava/721053.jpg',
#   './DataSet/images/baklava/722179.jpg',
#   './DataSet/images/baklava/72326.jpg',
#   './DataSet/images/baklava/724383.jpg',
#   './DataSet/images/baklava/734297.jpg',
#   './DataSet/images/baklava/758596.jpg',
#   './DataSet/images/baklava/763258.jpg',
#   './DataSet/images/baklava/788.jpg',
#   './DataSet/images/baklava/796010.jpg',
#   './DataSet/images/baklava/800666.jpg',
#   './DataSet/images/baklava/840044.jpg',
#   './DataSet/images/baklava/862581.jpg',
#   './DataSet/images/baklava/881362.jpg',
#   './DataSet/images/baklava/890847.jpg',
#   './DataSet/images/baklava/899196.jpg',
#   './DataSet/images/baklava/910559.jpg',
#   './DataSet/images/baklava/930650.jpg',
#   './DataSet/images/baklava/940134.jpg',
#   './DataSet/images/baklava/941312.jpg',
#   './DataSet/images/baklava/942743.jpg',
#   './DataSet/images/baklava/968365.jpg',
#   './DataSet/images/baklava/971742.jpg',
#   './DataSet/images/baklava/993668.jpg',
#   './DataSet/images/beef_carpaccio/100853.jpg',
#   './DataSet/images/beef_carpaccio/1012548.jpg',
#   './DataSet/images/beef_carpaccio/1044312.jpg',
#   './DataSet/images/beef_carpaccio/1056550.jpg',
#   './DataSet/images/beef_carpaccio/1073326.jpg',
#   './DataSet/images/beef_carpaccio/1076104.jpg',
#   './DataSet/images/beef_carpaccio/1139546.jpg',
#   './DataSet/images/beef_carpaccio/1147514.jpg',
#   './DataSet/images/beef_carpaccio/1165377.jpg',
#   './DataSet/images/beef_carpaccio/116895.jpg',
#   './DataSet/images/beef_carpaccio/1169625.jpg',
#   './DataSet/images/beef_carpaccio/1189532.jpg',
#   './DataSet/images/beef_carpaccio/1193737.jpg',
#   './DataSet/images/beef_carpaccio/1212091.jpg',
#   './DataSet/images/beef_carpaccio/1215782.jpg',
#   './DataSet/images/beef_carpaccio/1216433.jpg',
#   './DataSet/images/beef_carpaccio/1219988.jpg',
#   './DataSet/images/beef_carpaccio/1240408.jpg',
#   './DataSet/images/beef_carpaccio/1243667.jpg',
#   './DataSet/images/beef_carpaccio/1244594.jpg',
#   './DataSet/images/beef_carpaccio/1254686.jpg',
#   './DataSet/images/beef_carpaccio/127274.jpg',
#   './DataSet/images/beef_carpaccio/1281446.jpg',
#   './DataSet/images/beef_carpaccio/1283655.jpg',
#   './DataSet/images/beef_carpaccio/1305949.jpg',
#   './DataSet/images/beef_carpaccio/1307126.jpg',
#   './DataSet/images/beef_carpaccio/1309896.jpg',
#   './DataSet/images/beef_carpaccio/132214.jpg',
#   './DataSet/images/beef_carpaccio/1327341.jpg',
#   './DataSet/images/beef_carpaccio/1344628.jpg',
#   './DataSet/images/beef_carpaccio/1350256.jpg',
#   './DataSet/images/beef_carpaccio/1391584.jpg',
#   './DataSet/images/beef_carpaccio/1410854.jpg',
#   './DataSet/images/beef_carpaccio/1413739.jpg',
#   './DataSet/images/beef_carpaccio/1422496.jpg',
#   './DataSet/images/beef_carpaccio/1440469.jpg',
#   './DataSet/images/beef_carpaccio/1449190.jpg',
#   './DataSet/images/beef_carpaccio/145114.jpg',
#   './DataSet/images/beef_carpaccio/1487998.jpg',
#   './DataSet/images/beef_carpaccio/1488494.jpg',
#   './DataSet/images/beef_carpaccio/1490425.jpg',
#   './DataSet/images/beef_carpaccio/150760.jpg',
#   './DataSet/images/beef_carpaccio/1525582.jpg',
#   './DataSet/images/beef_carpaccio/153517.jpg',
#   './DataSet/images/beef_carpaccio/158624.jpg',
#   './DataSet/images/beef_carpaccio/1598003.jpg',
#   './DataSet/images/beef_carpaccio/1621486.jpg',
#   './DataSet/images/beef_carpaccio/1636003.jpg',
#   './DataSet/images/beef_carpaccio/1645760.jpg',
#   './DataSet/images/beef_carpaccio/1657743.jpg',
#   './DataSet/images/beef_carpaccio/1661531.jpg',
#   './DataSet/images/beef_carpaccio/1662207.jpg',
#   './DataSet/images/beef_carpaccio/1666577.jpg',
#   './DataSet/images/beef_carpaccio/1672341.jpg',
#   './DataSet/images/beef_carpaccio/1698187.jpg',
#   './DataSet/images/beef_carpaccio/1725022.jpg',
#   './DataSet/images/beef_carpaccio/1726589.jpg',
#   './DataSet/images/beef_carpaccio/1736023.jpg',
#   './DataSet/images/beef_carpaccio/1736103.jpg',
#   './DataSet/images/beef_carpaccio/1737830.jpg',
#   './DataSet/images/beef_carpaccio/1742911.jpg',
#   './DataSet/images/beef_carpaccio/1744294.jpg',
#   './DataSet/images/beef_carpaccio/1744946.jpg',
#   './DataSet/images/beef_carpaccio/1765131.jpg',
#   './DataSet/images/beef_carpaccio/1782141.jpg',
#   './DataSet/images/beef_carpaccio/1801501.jpg',
#   './DataSet/images/beef_carpaccio/1834023.jpg',
#   './DataSet/images/beef_carpaccio/1856680.jpg',
#   './DataSet/images/beef_carpaccio/1859387.jpg',
#   './DataSet/images/beef_carpaccio/1864287.jpg',
#   './DataSet/images/beef_carpaccio/1887574.jpg',
#   './DataSet/images/beef_carpaccio/1888322.jpg',
#   './DataSet/images/beef_carpaccio/1894239.jpg',
#   './DataSet/images/beef_carpaccio/1905801.jpg',
#   './DataSet/images/beef_carpaccio/1906055.jpg',
#   './DataSet/images/beef_carpaccio/1937269.jpg',
#   './DataSet/images/beef_carpaccio/195418.jpg',
#   './DataSet/images/beef_carpaccio/1990775.jpg',
#   './DataSet/images/beef_carpaccio/1995804.jpg',
#   './DataSet/images/beef_carpaccio/199682.jpg',
#   './DataSet/images/beef_carpaccio/2004560.jpg',
#   './DataSet/images/beef_carpaccio/2036572.jpg',
#   './DataSet/images/beef_carpaccio/2043824.jpg',
#   './DataSet/images/beef_carpaccio/2047053.jpg',
#   './DataSet/images/beef_carpaccio/206130.jpg',
#   './DataSet/images/beef_carpaccio/2072790.jpg',
#   './DataSet/images/beef_carpaccio/2081072.jpg',
#   './DataSet/images/beef_carpaccio/2082170.jpg',
#   './DataSet/images/beef_carpaccio/2082670.jpg',
#   './DataSet/images/beef_carpaccio/2093250.jpg',
#   './DataSet/images/beef_carpaccio/2098481.jpg',
#   './DataSet/images/beef_carpaccio/2107145.jpg',
#   './DataSet/images/beef_carpaccio/2107422.jpg',
#   './DataSet/images/beef_carpaccio/2111830.jpg',
#   './DataSet/images/beef_carpaccio/2125731.jpg',
#   './DataSet/images/beef_carpaccio/2145969.jpg',
#   './DataSet/images/beef_carpaccio/2152088.jpg',
#   './DataSet/images/beef_carpaccio/2155995.jpg',
#   './DataSet/images/beef_carpaccio/217698.jpg',
#   './DataSet/images/beef_carpaccio/2202234.jpg',
#   './DataSet/images/beef_carpaccio/2213150.jpg',
#   './DataSet/images/beef_carpaccio/2224419.jpg',
#   './DataSet/images/beef_carpaccio/2224490.jpg',
#   './DataSet/images/beef_carpaccio/2227816.jpg',
#   './DataSet/images/beef_carpaccio/223404.jpg',
#   './DataSet/images/beef_carpaccio/2250170.jpg',
#   './DataSet/images/beef_carpaccio/2257269.jpg',
#   './DataSet/images/beef_carpaccio/2269439.jpg',
#   './DataSet/images/beef_carpaccio/2294985.jpg',
#   './DataSet/images/beef_carpaccio/2298516.jpg',
#   './DataSet/images/beef_carpaccio/2305461.jpg',
#   './DataSet/images/beef_carpaccio/2352346.jpg',
#   './DataSet/images/beef_carpaccio/2420375.jpg',
#   './DataSet/images/beef_carpaccio/245298.jpg',
#   './DataSet/images/beef_carpaccio/2481212.jpg',
#   './DataSet/images/beef_carpaccio/2501787.jpg',
#   './DataSet/images/beef_carpaccio/2502843.jpg',
#   './DataSet/images/beef_carpaccio/2518192.jpg',
#   './DataSet/images/beef_carpaccio/2522462.jpg',
#   './DataSet/images/beef_carpaccio/2527037.jpg',
#   './DataSet/images/beef_carpaccio/2535555.jpg',
#   './DataSet/images/beef_carpaccio/2547400.jpg',
#   './DataSet/images/beef_carpaccio/2549446.jpg',
#   './DataSet/images/beef_carpaccio/257386.jpg',
#   './DataSet/images/beef_carpaccio/2587814.jpg',
#   './DataSet/images/beef_carpaccio/259203.jpg',
#   './DataSet/images/beef_carpaccio/2605475.jpg',
#   './DataSet/images/beef_carpaccio/262281.jpg',
#   './DataSet/images/beef_carpaccio/263713.jpg',
#   './DataSet/images/beef_carpaccio/2649866.jpg',
#   './DataSet/images/beef_carpaccio/2652547.jpg',
#   './DataSet/images/beef_carpaccio/2660378.jpg',
#   './DataSet/images/beef_carpaccio/2662677.jpg',
#   './DataSet/images/beef_carpaccio/266627.jpg',
#   './DataSet/images/beef_carpaccio/2698359.jpg',
#   './DataSet/images/beef_carpaccio/2704813.jpg',
#   './DataSet/images/beef_carpaccio/2855684.jpg',
#   './DataSet/images/beef_carpaccio/2855917.jpg',
#   './DataSet/images/beef_carpaccio/286992.jpg',
#   './DataSet/images/beef_carpaccio/2874813.jpg',
#   './DataSet/images/beef_carpaccio/2901949.jpg',
#   './DataSet/images/beef_carpaccio/2954930.jpg',
#   './DataSet/images/beef_carpaccio/2959284.jpg',
#   './DataSet/images/beef_carpaccio/2960202.jpg',
#   './DataSet/images/beef_carpaccio/298930.jpg',
#   './DataSet/images/beef_carpaccio/2999990.jpg',
#   './DataSet/images/beef_carpaccio/3009105.jpg',
#   './DataSet/images/beef_carpaccio/3022415.jpg',
#   './DataSet/images/beef_carpaccio/3026476.jpg',
#   './DataSet/images/beef_carpaccio/3031137.jpg',
#   './DataSet/images/beef_carpaccio/3034703.jpg',
#   './DataSet/images/beef_carpaccio/3040322.jpg',
#   './DataSet/images/beef_carpaccio/3047170.jpg',
#   './DataSet/images/beef_carpaccio/3048461.jpg',
#   './DataSet/images/beef_carpaccio/3048557.jpg',
#   './DataSet/images/beef_carpaccio/3049045.jpg',
#   './DataSet/images/beef_carpaccio/3057236.jpg',
#   './DataSet/images/beef_carpaccio/3068895.jpg',
#   './DataSet/images/beef_carpaccio/3110371.jpg',
#   './DataSet/images/beef_carpaccio/3114203.jpg',
#   './DataSet/images/beef_carpaccio/3136478.jpg',
#   './DataSet/images/beef_carpaccio/3156761.jpg',
#   './DataSet/images/beef_carpaccio/3173328.jpg',
#   './DataSet/images/beef_carpaccio/3173456.jpg',
#   './DataSet/images/beef_carpaccio/3177871.jpg',
#   './DataSet/images/beef_carpaccio/3184691.jpg',
#   './DataSet/images/beef_carpaccio/3186071.jpg',
#   './DataSet/images/beef_carpaccio/3187459.jpg',
#   './DataSet/images/beef_carpaccio/3213562.jpg',
#   './DataSet/images/beef_carpaccio/3216827.jpg',
#   './DataSet/images/beef_carpaccio/3233471.jpg',
#   './DataSet/images/beef_carpaccio/3246745.jpg',
#   './DataSet/images/beef_carpaccio/3251998.jpg',
#   './DataSet/images/beef_carpaccio/3274204.jpg',
#   './DataSet/images/beef_carpaccio/3275686.jpg',
#   './DataSet/images/beef_carpaccio/3289048.jpg',
#   './DataSet/images/beef_carpaccio/3293967.jpg',
#   './DataSet/images/beef_carpaccio/3296135.jpg',
#   './DataSet/images/beef_carpaccio/331923.jpg',
#   './DataSet/images/beef_carpaccio/3323312.jpg',
#   './DataSet/images/beef_carpaccio/3324958.jpg',
#   './DataSet/images/beef_carpaccio/3348946.jpg',
#   './DataSet/images/beef_carpaccio/3351953.jpg',
#   './DataSet/images/beef_carpaccio/3394024.jpg',
#   './DataSet/images/beef_carpaccio/3397060.jpg',
#   './DataSet/images/beef_carpaccio/3418483.jpg',
#   './DataSet/images/beef_carpaccio/3453461.jpg',
#   './DataSet/images/beef_carpaccio/3469865.jpg',
#   './DataSet/images/beef_carpaccio/3473722.jpg',
#   './DataSet/images/beef_carpaccio/3477399.jpg',
#   './DataSet/images/beef_carpaccio/3501900.jpg',
#   './DataSet/images/beef_carpaccio/3503609.jpg',
#   './DataSet/images/beef_carpaccio/3526861.jpg',
#   './DataSet/images/beef_carpaccio/3554546.jpg',
#   './DataSet/images/beef_carpaccio/356619.jpg',
#   './DataSet/images/beef_carpaccio/3601506.jpg',
#   './DataSet/images/beef_carpaccio/3669360.jpg',
#   './DataSet/images/beef_carpaccio/3683582.jpg',
#   './DataSet/images/beef_carpaccio/3691772.jpg',
#   './DataSet/images/beef_carpaccio/3695049.jpg',
#   './DataSet/images/beef_carpaccio/3698441.jpg',
#   './DataSet/images/beef_carpaccio/3714848.jpg',
#   './DataSet/images/beef_carpaccio/3715270.jpg',
#   './DataSet/images/beef_carpaccio/372148.jpg',
#   './DataSet/images/beef_carpaccio/3763726.jpg',
#   './DataSet/images/beef_carpaccio/3769247.jpg',
#   './DataSet/images/beef_carpaccio/3806863.jpg',
#   './DataSet/images/beef_carpaccio/3824578.jpg',
#   './DataSet/images/beef_carpaccio/3851776.jpg',
#   './DataSet/images/beef_carpaccio/3868777.jpg',
#   './DataSet/images/beef_carpaccio/3889985.jpg',
#   './DataSet/images/beef_carpaccio/3890359.jpg',
#   './DataSet/images/beef_carpaccio/3896605.jpg',
#   './DataSet/images/beef_carpaccio/3914142.jpg',
#   './DataSet/images/beef_carpaccio/3914776.jpg',
#   './DataSet/images/beef_carpaccio/393798.jpg',
#   './DataSet/images/beef_carpaccio/466766.jpg',
#   './DataSet/images/beef_carpaccio/469347.jpg',
#   './DataSet/images/beef_carpaccio/470891.jpg',
#   './DataSet/images/beef_carpaccio/484148.jpg',
#   './DataSet/images/beef_carpaccio/498896.jpg',
#   './DataSet/images/beef_carpaccio/499131.jpg',
#   './DataSet/images/beef_carpaccio/559236.jpg',
#   './DataSet/images/beef_carpaccio/625990.jpg',
#   './DataSet/images/beef_carpaccio/652322.jpg',
#   './DataSet/images/beef_carpaccio/71477.jpg',
#   './DataSet/images/beef_carpaccio/720185.jpg',
#   './DataSet/images/beef_carpaccio/724709.jpg',
#   './DataSet/images/beef_carpaccio/728710.jpg',
#   './DataSet/images/beef_carpaccio/731242.jpg',
#   './DataSet/images/beef_carpaccio/743316.jpg',
#   './DataSet/images/beef_carpaccio/754565.jpg',
#   './DataSet/images/beef_carpaccio/776057.jpg',
#   './DataSet/images/beef_carpaccio/78744.jpg',
#   './DataSet/images/beef_carpaccio/791096.jpg',
#   './DataSet/images/beef_carpaccio/792439.jpg',
#   './DataSet/images/beef_carpaccio/795452.jpg',
#   './DataSet/images/beef_carpaccio/797039.jpg',
#   './DataSet/images/beef_carpaccio/826914.jpg',
#   './DataSet/images/beef_carpaccio/838353.jpg',
#   './DataSet/images/beef_carpaccio/859482.jpg',
#   './DataSet/images/beef_carpaccio/878644.jpg',
#   './DataSet/images/beef_carpaccio/887024.jpg',
#   './DataSet/images/beef_carpaccio/898749.jpg',
#   './DataSet/images/beef_carpaccio/919508.jpg',
#   './DataSet/images/beef_carpaccio/921303.jpg',
#   './DataSet/images/beef_carpaccio/925163.jpg',
#   './DataSet/images/beef_carpaccio/945594.jpg',
#   './DataSet/images/beef_carpaccio/984068.jpg',
#   './DataSet/images/beef_carpaccio/993482.jpg',
#   ...],
#  'label': ['apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'baklava',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   'beef_carpaccio',
#   ...]}

# %%
train = {}
image = []
label = []
with open('./DataSet/meta/meta/train.txt', 'r') as file:

    for line in file:
        text = line.strip()
        before, after = text.split("/")
        after = "./DataSet/images/" + before + "/" + after + ".jpg"
        image.append(after)
        label.append(before)
    
    train["image"] = image
    train["label"] = label

train
# Out:
# {'image': ['./DataSet/images/apple_pie/1005649.jpg',
#   './DataSet/images/apple_pie/1014775.jpg',
#   './DataSet/images/apple_pie/1026328.jpg',
#   './DataSet/images/apple_pie/1028787.jpg',
#   './DataSet/images/apple_pie/1043283.jpg',
#   './DataSet/images/apple_pie/1050519.jpg',
#   './DataSet/images/apple_pie/1057749.jpg',
#   './DataSet/images/apple_pie/1057810.jpg',
#   './DataSet/images/apple_pie/1072416.jpg',
#   './DataSet/images/apple_pie/1074856.jpg',
#   './DataSet/images/apple_pie/1074942.jpg',
#   './DataSet/images/apple_pie/1076891.jpg',
#   './DataSet/images/apple_pie/1077610.jpg',
#   './DataSet/images/apple_pie/1077964.jpg',
#   './DataSet/images/apple_pie/1088809.jpg',
#   './DataSet/images/apple_pie/1097378.jpg',
#   './DataSet/images/apple_pie/1103795.jpg',
#   './DataSet/images/apple_pie/1109597.jpg',
#   './DataSet/images/apple_pie/1111062.jpg',
#   './DataSet/images/apple_pie/1112300.jpg',
#   './DataSet/images/apple_pie/1112838.jpg',
#   './DataSet/images/apple_pie/1121884.jpg',
#   './DataSet/images/apple_pie/112378.jpg',
#   './DataSet/images/apple_pie/1133267.jpg',
#   './DataSet/images/apple_pie/1142597.jpg',
#   './DataSet/images/apple_pie/1147371.jpg',
#   './DataSet/images/apple_pie/1154371.jpg',
#   './DataSet/images/apple_pie/1158360.jpg',
#   './DataSet/images/apple_pie/1159801.jpg',
#   './DataSet/images/apple_pie/1165004.jpg',
#   './DataSet/images/apple_pie/1166116.jpg',
#   './DataSet/images/apple_pie/1166210.jpg',
#   './DataSet/images/apple_pie/116697.jpg',
#   './DataSet/images/apple_pie/1174241.jpg',
#   './DataSet/images/apple_pie/1174949.jpg',
#   './DataSet/images/apple_pie/1177254.jpg',
#   './DataSet/images/apple_pie/118237.jpg',
#   './DataSet/images/apple_pie/1184568.jpg',
#   './DataSet/images/apple_pie/1185445.jpg',
#   './DataSet/images/apple_pie/1185654.jpg',
#   './DataSet/images/apple_pie/1191665.jpg',
#   './DataSet/images/apple_pie/1196628.jpg',
#   './DataSet/images/apple_pie/1199851.jpg',
#   './DataSet/images/apple_pie/1200079.jpg',
#   './DataSet/images/apple_pie/1214326.jpg',
#   './DataSet/images/apple_pie/1215650.jpg',
#   './DataSet/images/apple_pie/1218767.jpg',
#   './DataSet/images/apple_pie/1220194.jpg',
#   './DataSet/images/apple_pie/1230465.jpg',
#   './DataSet/images/apple_pie/1232311.jpg',
#   './DataSet/images/apple_pie/123782.jpg',
#   './DataSet/images/apple_pie/1239205.jpg',
#   './DataSet/images/apple_pie/1240585.jpg',
#   './DataSet/images/apple_pie/1246460.jpg',
#   './DataSet/images/apple_pie/1246552.jpg',
#   './DataSet/images/apple_pie/1252879.jpg',
#   './DataSet/images/apple_pie/1264435.jpg',
#   './DataSet/images/apple_pie/1265307.jpg',
#   './DataSet/images/apple_pie/1272778.jpg',
#   './DataSet/images/apple_pie/127721.jpg',
#   './DataSet/images/apple_pie/1280767.jpg',
#   './DataSet/images/apple_pie/128259.jpg',
#   './DataSet/images/apple_pie/1284682.jpg',
#   './DataSet/images/apple_pie/1289014.jpg',
#   './DataSet/images/apple_pie/1290425.jpg',
#   './DataSet/images/apple_pie/1305678.jpg',
#   './DataSet/images/apple_pie/1322211.jpg',
#   './DataSet/images/apple_pie/1323309.jpg',
#   './DataSet/images/apple_pie/1335563.jpg',
#   './DataSet/images/apple_pie/134.jpg',
#   './DataSet/images/apple_pie/1340287.jpg',
#   './DataSet/images/apple_pie/1343307.jpg',
#   './DataSet/images/apple_pie/1344873.jpg',
#   './DataSet/images/apple_pie/1346262.jpg',
#   './DataSet/images/apple_pie/1348788.jpg',
#   './DataSet/images/apple_pie/1350394.jpg',
#   './DataSet/images/apple_pie/1354215.jpg',
#   './DataSet/images/apple_pie/1355206.jpg',
#   './DataSet/images/apple_pie/1357950.jpg',
#   './DataSet/images/apple_pie/1361950.jpg',
#   './DataSet/images/apple_pie/136256.jpg',
#   './DataSet/images/apple_pie/1376013.jpg',
#   './DataSet/images/apple_pie/1379062.jpg',
#   './DataSet/images/apple_pie/1391393.jpg',
#   './DataSet/images/apple_pie/1392703.jpg',
#   './DataSet/images/apple_pie/1397313.jpg',
#   './DataSet/images/apple_pie/1399051.jpg',
#   './DataSet/images/apple_pie/1406371.jpg',
#   './DataSet/images/apple_pie/1410907.jpg',
#   './DataSet/images/apple_pie/1416578.jpg',
#   './DataSet/images/apple_pie/1420227.jpg',
#   './DataSet/images/apple_pie/1421796.jpg',
#   './DataSet/images/apple_pie/142332.jpg',
#   './DataSet/images/apple_pie/1428585.jpg',
#   './DataSet/images/apple_pie/1442421.jpg',
#   './DataSet/images/apple_pie/1443243.jpg',
#   './DataSet/images/apple_pie/1445323.jpg',
#   './DataSet/images/apple_pie/1447062.jpg',
#   './DataSet/images/apple_pie/1448488.jpg',
#   './DataSet/images/apple_pie/1450514.jpg',
#   './DataSet/images/apple_pie/1456028.jpg',
#   './DataSet/images/apple_pie/1456379.jpg',
#   './DataSet/images/apple_pie/1464079.jpg',
#   './DataSet/images/apple_pie/1466791.jpg',
#   './DataSet/images/apple_pie/1481550.jpg',
#   './DataSet/images/apple_pie/1484086.jpg',
#   './DataSet/images/apple_pie/1486972.jpg',
#   './DataSet/images/apple_pie/1487150.jpg',
#   './DataSet/images/apple_pie/1488583.jpg',
#   './DataSet/images/apple_pie/1491146.jpg',
#   './DataSet/images/apple_pie/1498817.jpg',
#   './DataSet/images/apple_pie/1503274.jpg',
#   './DataSet/images/apple_pie/1528187.jpg',
#   './DataSet/images/apple_pie/1528623.jpg',
#   './DataSet/images/apple_pie/1544507.jpg',
#   './DataSet/images/apple_pie/1547651.jpg',
#   './DataSet/images/apple_pie/1550786.jpg',
#   './DataSet/images/apple_pie/1558003.jpg',
#   './DataSet/images/apple_pie/1558101.jpg',
#   './DataSet/images/apple_pie/156078.jpg',
#   './DataSet/images/apple_pie/157083.jpg',
#   './DataSet/images/apple_pie/1575505.jpg',
#   './DataSet/images/apple_pie/1580276.jpg',
#   './DataSet/images/apple_pie/1581291.jpg',
#   './DataSet/images/apple_pie/1581853.jpg',
#   './DataSet/images/apple_pie/1586889.jpg',
#   './DataSet/images/apple_pie/1595134.jpg',
#   './DataSet/images/apple_pie/1596650.jpg',
#   './DataSet/images/apple_pie/1596752.jpg',
#   './DataSet/images/apple_pie/1620714.jpg',
#   './DataSet/images/apple_pie/1622276.jpg',
#   './DataSet/images/apple_pie/1633183.jpg',
#   './DataSet/images/apple_pie/1633812.jpg',
#   './DataSet/images/apple_pie/1646808.jpg',
#   './DataSet/images/apple_pie/1648647.jpg',
#   './DataSet/images/apple_pie/1659828.jpg',
#   './DataSet/images/apple_pie/1667135.jpg',
#   './DataSet/images/apple_pie/1670009.jpg',
#   './DataSet/images/apple_pie/1677760.jpg',
#   './DataSet/images/apple_pie/1689411.jpg',
#   './DataSet/images/apple_pie/1698156.jpg',
#   './DataSet/images/apple_pie/1700578.jpg',
#   './DataSet/images/apple_pie/1710288.jpg',
#   './DataSet/images/apple_pie/1717754.jpg',
#   './DataSet/images/apple_pie/1725573.jpg',
#   './DataSet/images/apple_pie/1725747.jpg',
#   './DataSet/images/apple_pie/1727085.jpg',
#   './DataSet/images/apple_pie/1735072.jpg',
#   './DataSet/images/apple_pie/1739519.jpg',
#   './DataSet/images/apple_pie/1753164.jpg',
#   './DataSet/images/apple_pie/1753171.jpg',
#   './DataSet/images/apple_pie/1753935.jpg',
#   './DataSet/images/apple_pie/1756344.jpg',
#   './DataSet/images/apple_pie/1764457.jpg',
#   './DataSet/images/apple_pie/1766910.jpg',
#   './DataSet/images/apple_pie/1767333.jpg',
#   './DataSet/images/apple_pie/1771395.jpg',
#   './DataSet/images/apple_pie/1786261.jpg',
#   './DataSet/images/apple_pie/1789100.jpg',
#   './DataSet/images/apple_pie/1790730.jpg',
#   './DataSet/images/apple_pie/1810149.jpg',
#   './DataSet/images/apple_pie/1815972.jpg',
#   './DataSet/images/apple_pie/1816741.jpg',
#   './DataSet/images/apple_pie/1818676.jpg',
#   './DataSet/images/apple_pie/1819763.jpg',
#   './DataSet/images/apple_pie/1820074.jpg',
#   './DataSet/images/apple_pie/1822764.jpg',
#   './DataSet/images/apple_pie/182745.jpg',
#   './DataSet/images/apple_pie/1830100.jpg',
#   './DataSet/images/apple_pie/1830215.jpg',
#   './DataSet/images/apple_pie/1830582.jpg',
#   './DataSet/images/apple_pie/1840575.jpg',
#   './DataSet/images/apple_pie/1847944.jpg',
#   './DataSet/images/apple_pie/185537.jpg',
#   './DataSet/images/apple_pie/1873576.jpg',
#   './DataSet/images/apple_pie/1874318.jpg',
#   './DataSet/images/apple_pie/1874325.jpg',
#   './DataSet/images/apple_pie/1879193.jpg',
#   './DataSet/images/apple_pie/1886600.jpg',
#   './DataSet/images/apple_pie/1886694.jpg',
#   './DataSet/images/apple_pie/1895811.jpg',
#   './DataSet/images/apple_pie/1897389.jpg',
#   './DataSet/images/apple_pie/1899134.jpg',
#   './DataSet/images/apple_pie/1914188.jpg',
#   './DataSet/images/apple_pie/1923768.jpg',
#   './DataSet/images/apple_pie/1931301.jpg',
#   './DataSet/images/apple_pie/1936913.jpg',
#   './DataSet/images/apple_pie/1939853.jpg',
#   './DataSet/images/apple_pie/1941412.jpg',
#   './DataSet/images/apple_pie/1944962.jpg',
#   './DataSet/images/apple_pie/1946376.jpg',
#   './DataSet/images/apple_pie/195087.jpg',
#   './DataSet/images/apple_pie/1954841.jpg',
#   './DataSet/images/apple_pie/1963597.jpg',
#   './DataSet/images/apple_pie/1969851.jpg',
#   './DataSet/images/apple_pie/1977565.jpg',
#   './DataSet/images/apple_pie/1984895.jpg',
#   './DataSet/images/apple_pie/1988310.jpg',
#   './DataSet/images/apple_pie/1990658.jpg',
#   './DataSet/images/apple_pie/1994318.jpg',
#   './DataSet/images/apple_pie/1995380.jpg',
#   './DataSet/images/apple_pie/2004963.jpg',
#   './DataSet/images/apple_pie/2008772.jpg',
#   './DataSet/images/apple_pie/2012973.jpg',
#   './DataSet/images/apple_pie/2023705.jpg',
#   './DataSet/images/apple_pie/202741.jpg',
#   './DataSet/images/apple_pie/2030311.jpg',
#   './DataSet/images/apple_pie/2034923.jpg',
#   './DataSet/images/apple_pie/2047916.jpg',
#   './DataSet/images/apple_pie/2051864.jpg',
#   './DataSet/images/apple_pie/205716.jpg',
#   './DataSet/images/apple_pie/2067073.jpg',
#   './DataSet/images/apple_pie/2068700.jpg',
#   './DataSet/images/apple_pie/2074865.jpg',
#   './DataSet/images/apple_pie/2075376.jpg',
#   './DataSet/images/apple_pie/208041.jpg',
#   './DataSet/images/apple_pie/2086645.jpg',
#   './DataSet/images/apple_pie/2088064.jpg',
#   './DataSet/images/apple_pie/2101662.jpg',
#   './DataSet/images/apple_pie/2106005.jpg',
#   './DataSet/images/apple_pie/21063.jpg',
#   './DataSet/images/apple_pie/2110106.jpg',
#   './DataSet/images/apple_pie/2111966.jpg',
#   './DataSet/images/apple_pie/2126901.jpg',
#   './DataSet/images/apple_pie/2132230.jpg',
#   './DataSet/images/apple_pie/2133067.jpg',
#   './DataSet/images/apple_pie/2143318.jpg',
#   './DataSet/images/apple_pie/214334.jpg',
#   './DataSet/images/apple_pie/2151461.jpg',
#   './DataSet/images/apple_pie/2153869.jpg',
#   './DataSet/images/apple_pie/2157956.jpg',
#   './DataSet/images/apple_pie/2163544.jpg',
#   './DataSet/images/apple_pie/2171324.jpg',
#   './DataSet/images/apple_pie/2178254.jpg',
#   './DataSet/images/apple_pie/2195793.jpg',
#   './DataSet/images/apple_pie/2200328.jpg',
#   './DataSet/images/apple_pie/2202694.jpg',
#   './DataSet/images/apple_pie/2205061.jpg',
#   './DataSet/images/apple_pie/222074.jpg',
#   './DataSet/images/apple_pie/2223296.jpg',
#   './DataSet/images/apple_pie/2223847.jpg',
#   './DataSet/images/apple_pie/2224273.jpg',
#   './DataSet/images/apple_pie/2231842.jpg',
#   './DataSet/images/apple_pie/2235547.jpg',
#   './DataSet/images/apple_pie/2235729.jpg',
#   './DataSet/images/apple_pie/2239083.jpg',
#   './DataSet/images/apple_pie/2245633.jpg',
#   './DataSet/images/apple_pie/2245635.jpg',
#   './DataSet/images/apple_pie/2248020.jpg',
#   './DataSet/images/apple_pie/2267350.jpg',
#   './DataSet/images/apple_pie/2288697.jpg',
#   './DataSet/images/apple_pie/2298862.jpg',
#   './DataSet/images/apple_pie/2302866.jpg',
#   './DataSet/images/apple_pie/2303859.jpg',
#   './DataSet/images/apple_pie/2306493.jpg',
#   './DataSet/images/apple_pie/2320000.jpg',
#   './DataSet/images/apple_pie/2323355.jpg',
#   './DataSet/images/apple_pie/2328227.jpg',
#   './DataSet/images/apple_pie/2335873.jpg',
#   './DataSet/images/apple_pie/2337097.jpg',
#   './DataSet/images/apple_pie/2337652.jpg',
#   './DataSet/images/apple_pie/2339010.jpg',
#   './DataSet/images/apple_pie/2345199.jpg',
#   './DataSet/images/apple_pie/2347111.jpg',
#   './DataSet/images/apple_pie/2348133.jpg',
#   './DataSet/images/apple_pie/235537.jpg',
#   './DataSet/images/apple_pie/2361153.jpg',
#   './DataSet/images/apple_pie/2364059.jpg',
#   './DataSet/images/apple_pie/2369640.jpg',
#   './DataSet/images/apple_pie/236966.jpg',
#   './DataSet/images/apple_pie/2379223.jpg',
#   './DataSet/images/apple_pie/2383378.jpg',
#   './DataSet/images/apple_pie/238868.jpg',
#   './DataSet/images/apple_pie/23893.jpg',
#   './DataSet/images/apple_pie/2391509.jpg',
#   './DataSet/images/apple_pie/2400434.jpg',
#   './DataSet/images/apple_pie/2408052.jpg',
#   './DataSet/images/apple_pie/2412284.jpg',
#   './DataSet/images/apple_pie/2416573.jpg',
#   './DataSet/images/apple_pie/2421227.jpg',
#   './DataSet/images/apple_pie/2434963.jpg',
#   './DataSet/images/apple_pie/2439188.jpg',
#   './DataSet/images/apple_pie/2447106.jpg',
#   './DataSet/images/apple_pie/2447421.jpg',
#   './DataSet/images/apple_pie/2451702.jpg',
#   './DataSet/images/apple_pie/2453243.jpg',
#   './DataSet/images/apple_pie/245712.jpg',
#   './DataSet/images/apple_pie/2458159.jpg',
#   './DataSet/images/apple_pie/2479319.jpg',
#   './DataSet/images/apple_pie/2480328.jpg',
#   './DataSet/images/apple_pie/2485958.jpg',
#   './DataSet/images/apple_pie/2486622.jpg',
#   './DataSet/images/apple_pie/2490410.jpg',
#   './DataSet/images/apple_pie/2510497.jpg',
#   './DataSet/images/apple_pie/2517642.jpg',
#   './DataSet/images/apple_pie/2518174.jpg',
#   './DataSet/images/apple_pie/2519446.jpg',
#   './DataSet/images/apple_pie/2520241.jpg',
#   './DataSet/images/apple_pie/2520431.jpg',
#   './DataSet/images/apple_pie/2523745.jpg',
#   './DataSet/images/apple_pie/2527163.jpg',
#   './DataSet/images/apple_pie/2528236.jpg',
#   './DataSet/images/apple_pie/2536578.jpg',
#   './DataSet/images/apple_pie/2538221.jpg',
#   './DataSet/images/apple_pie/2540831.jpg',
#   './DataSet/images/apple_pie/2542633.jpg',
#   './DataSet/images/apple_pie/2546216.jpg',
#   './DataSet/images/apple_pie/2548878.jpg',
#   './DataSet/images/apple_pie/2564881.jpg',
#   './DataSet/images/apple_pie/2569986.jpg',
#   './DataSet/images/apple_pie/2570111.jpg',
#   './DataSet/images/apple_pie/257378.jpg',
#   './DataSet/images/apple_pie/2574026.jpg',
#   './DataSet/images/apple_pie/2579504.jpg',
#   './DataSet/images/apple_pie/2581687.jpg',
#   './DataSet/images/apple_pie/2582077.jpg',
#   './DataSet/images/apple_pie/2586142.jpg',
#   './DataSet/images/apple_pie/2586267.jpg',
#   './DataSet/images/apple_pie/2591737.jpg',
#   './DataSet/images/apple_pie/2595208.jpg',
#   './DataSet/images/apple_pie/2598068.jpg',
#   './DataSet/images/apple_pie/259923.jpg',
#   './DataSet/images/apple_pie/2600379.jpg',
#   './DataSet/images/apple_pie/2601590.jpg',
#   './DataSet/images/apple_pie/2601920.jpg',
#   './DataSet/images/apple_pie/2602468.jpg',
#   './DataSet/images/apple_pie/2603533.jpg',
#   './DataSet/images/apple_pie/2605371.jpg',
#   './DataSet/images/apple_pie/2605751.jpg',
#   './DataSet/images/apple_pie/2606415.jpg',
#   './DataSet/images/apple_pie/2607306.jpg',
#   './DataSet/images/apple_pie/2607694.jpg',
#   './DataSet/images/apple_pie/2610017.jpg',
#   './DataSet/images/apple_pie/2612593.jpg',
#   './DataSet/images/apple_pie/2615584.jpg',
#   './DataSet/images/apple_pie/2620367.jpg',
#   './DataSet/images/apple_pie/2621542.jpg',
#   './DataSet/images/apple_pie/2626973.jpg',
#   './DataSet/images/apple_pie/2627767.jpg',
#   './DataSet/images/apple_pie/2635983.jpg',
#   './DataSet/images/apple_pie/2648160.jpg',
#   './DataSet/images/apple_pie/2651801.jpg',
#   './DataSet/images/apple_pie/2656095.jpg',
#   './DataSet/images/apple_pie/2658301.jpg',
#   './DataSet/images/apple_pie/265928.jpg',
#   './DataSet/images/apple_pie/266007.jpg',
#   './DataSet/images/apple_pie/2666921.jpg',
#   './DataSet/images/apple_pie/2677312.jpg',
#   './DataSet/images/apple_pie/267865.jpg',
#   './DataSet/images/apple_pie/2682484.jpg',
#   './DataSet/images/apple_pie/2683315.jpg',
#   './DataSet/images/apple_pie/2698000.jpg',
#   './DataSet/images/apple_pie/2702725.jpg',
#   './DataSet/images/apple_pie/2704442.jpg',
#   './DataSet/images/apple_pie/2705419.jpg',
#   './DataSet/images/apple_pie/2708417.jpg',
#   './DataSet/images/apple_pie/2713482.jpg',
#   './DataSet/images/apple_pie/2713820.jpg',
#   './DataSet/images/apple_pie/2721937.jpg',
#   './DataSet/images/apple_pie/2722097.jpg',
#   './DataSet/images/apple_pie/2722635.jpg',
#   './DataSet/images/apple_pie/2724897.jpg',
#   './DataSet/images/apple_pie/2725375.jpg',
#   './DataSet/images/apple_pie/2735083.jpg',
#   './DataSet/images/apple_pie/2735451.jpg',
#   './DataSet/images/apple_pie/2740775.jpg',
#   './DataSet/images/apple_pie/2740848.jpg',
#   './DataSet/images/apple_pie/274516.jpg',
#   './DataSet/images/apple_pie/2745186.jpg',
#   './DataSet/images/apple_pie/2745241.jpg',
#   './DataSet/images/apple_pie/2751362.jpg',
#   './DataSet/images/apple_pie/2751755.jpg',
#   './DataSet/images/apple_pie/2761063.jpg',
#   './DataSet/images/apple_pie/2761976.jpg',
#   './DataSet/images/apple_pie/2762199.jpg',
#   './DataSet/images/apple_pie/2764233.jpg',
#   './DataSet/images/apple_pie/2764778.jpg',
#   './DataSet/images/apple_pie/2766379.jpg',
#   './DataSet/images/apple_pie/2766609.jpg',
#   './DataSet/images/apple_pie/2766725.jpg',
#   './DataSet/images/apple_pie/2767057.jpg',
#   './DataSet/images/apple_pie/2768268.jpg',
#   './DataSet/images/apple_pie/2769307.jpg',
#   './DataSet/images/apple_pie/2769368.jpg',
#   './DataSet/images/apple_pie/2769470.jpg',
#   './DataSet/images/apple_pie/2776008.jpg',
#   './DataSet/images/apple_pie/2777088.jpg',
#   './DataSet/images/apple_pie/2777273.jpg',
#   './DataSet/images/apple_pie/2781167.jpg',
#   './DataSet/images/apple_pie/2782050.jpg',
#   './DataSet/images/apple_pie/2782633.jpg',
#   './DataSet/images/apple_pie/2785030.jpg',
#   './DataSet/images/apple_pie/2799681.jpg',
#   './DataSet/images/apple_pie/2800543.jpg',
#   './DataSet/images/apple_pie/280199.jpg',
#   './DataSet/images/apple_pie/2804953.jpg',
#   './DataSet/images/apple_pie/2806926.jpg',
#   './DataSet/images/apple_pie/2812998.jpg',
#   './DataSet/images/apple_pie/2819375.jpg',
#   './DataSet/images/apple_pie/2819833.jpg',
#   './DataSet/images/apple_pie/282352.jpg',
#   './DataSet/images/apple_pie/2825284.jpg',
#   './DataSet/images/apple_pie/2828161.jpg',
#   './DataSet/images/apple_pie/2839261.jpg',
#   './DataSet/images/apple_pie/2839283.jpg',
#   './DataSet/images/apple_pie/2840005.jpg',
#   './DataSet/images/apple_pie/2847214.jpg',
#   './DataSet/images/apple_pie/2851371.jpg',
#   './DataSet/images/apple_pie/2853890.jpg',
#   './DataSet/images/apple_pie/2854105.jpg',
#   './DataSet/images/apple_pie/285509.jpg',
#   './DataSet/images/apple_pie/2856273.jpg',
#   './DataSet/images/apple_pie/2856319.jpg',
#   './DataSet/images/apple_pie/2861144.jpg',
#   './DataSet/images/apple_pie/2869633.jpg',
#   './DataSet/images/apple_pie/2872568.jpg',
#   './DataSet/images/apple_pie/2874860.jpg',
#   './DataSet/images/apple_pie/2900219.jpg',
#   './DataSet/images/apple_pie/2902847.jpg',
#   './DataSet/images/apple_pie/2909830.jpg',
#   './DataSet/images/apple_pie/2911613.jpg',
#   './DataSet/images/apple_pie/2914000.jpg',
#   './DataSet/images/apple_pie/2915359.jpg',
#   './DataSet/images/apple_pie/2918880.jpg',
#   './DataSet/images/apple_pie/2921600.jpg',
#   './DataSet/images/apple_pie/2922138.jpg',
#   './DataSet/images/apple_pie/292333.jpg',
#   './DataSet/images/apple_pie/2924795.jpg',
#   './DataSet/images/apple_pie/2928660.jpg',
#   './DataSet/images/apple_pie/2929330.jpg',
#   './DataSet/images/apple_pie/2929448.jpg',
#   './DataSet/images/apple_pie/2934928.jpg',
#   './DataSet/images/apple_pie/293530.jpg',
#   './DataSet/images/apple_pie/2940483.jpg',
#   './DataSet/images/apple_pie/2955004.jpg',
#   './DataSet/images/apple_pie/2956823.jpg',
#   './DataSet/images/apple_pie/2961406.jpg',
#   './DataSet/images/apple_pie/2961496.jpg',
#   './DataSet/images/apple_pie/2967700.jpg',
#   './DataSet/images/apple_pie/2968495.jpg',
#   './DataSet/images/apple_pie/2969119.jpg',
#   './DataSet/images/apple_pie/2975948.jpg',
#   './DataSet/images/apple_pie/2977851.jpg',
#   './DataSet/images/apple_pie/2986199.jpg',
#   './DataSet/images/apple_pie/2989031.jpg',
#   './DataSet/images/apple_pie/2989799.jpg',
#   './DataSet/images/apple_pie/2994917.jpg',
#   './DataSet/images/apple_pie/2995608.jpg',
#   './DataSet/images/apple_pie/2997124.jpg',
#   './DataSet/images/apple_pie/299931.jpg',
#   './DataSet/images/apple_pie/3004621.jpg',
#   './DataSet/images/apple_pie/3018695.jpg',
#   './DataSet/images/apple_pie/3021995.jpg',
#   './DataSet/images/apple_pie/3023096.jpg',
#   './DataSet/images/apple_pie/3025907.jpg',
#   './DataSet/images/apple_pie/3031488.jpg',
#   './DataSet/images/apple_pie/3047214.jpg',
#   './DataSet/images/apple_pie/3059110.jpg',
#   './DataSet/images/apple_pie/3059134.jpg',
#   './DataSet/images/apple_pie/3065929.jpg',
#   './DataSet/images/apple_pie/3079946.jpg',
#   './DataSet/images/apple_pie/3096075.jpg',
#   './DataSet/images/apple_pie/3098981.jpg',
#   './DataSet/images/apple_pie/3103489.jpg',
#   './DataSet/images/apple_pie/3108401.jpg',
#   './DataSet/images/apple_pie/3110084.jpg',
#   './DataSet/images/apple_pie/3113710.jpg',
#   './DataSet/images/apple_pie/3116086.jpg',
#   './DataSet/images/apple_pie/3127422.jpg',
#   './DataSet/images/apple_pie/3128330.jpg',
#   './DataSet/images/apple_pie/3132437.jpg',
#   './DataSet/images/apple_pie/3134347.jpg',
#   './DataSet/images/apple_pie/3139762.jpg',
#   './DataSet/images/apple_pie/3140647.jpg',
#   './DataSet/images/apple_pie/3158095.jpg',
#   './DataSet/images/apple_pie/3175105.jpg',
#   './DataSet/images/apple_pie/3176186.jpg',
#   './DataSet/images/apple_pie/3177727.jpg',
#   './DataSet/images/apple_pie/3191226.jpg',
#   './DataSet/images/apple_pie/3192077.jpg',
#   './DataSet/images/apple_pie/3192774.jpg',
#   './DataSet/images/apple_pie/3197173.jpg',
#   './DataSet/images/apple_pie/3198655.jpg',
#   './DataSet/images/apple_pie/3203950.jpg',
#   './DataSet/images/apple_pie/3209538.jpg',
#   './DataSet/images/apple_pie/3211704.jpg',
#   './DataSet/images/apple_pie/321197.jpg',
#   './DataSet/images/apple_pie/3214508.jpg',
#   './DataSet/images/apple_pie/3217969.jpg',
#   './DataSet/images/apple_pie/3226877.jpg',
#   './DataSet/images/apple_pie/323108.jpg',
#   './DataSet/images/apple_pie/3233920.jpg',
#   './DataSet/images/apple_pie/3236737.jpg',
#   './DataSet/images/apple_pie/3241750.jpg',
#   './DataSet/images/apple_pie/3242445.jpg',
#   './DataSet/images/apple_pie/3251989.jpg',
#   './DataSet/images/apple_pie/3252424.jpg',
#   './DataSet/images/apple_pie/3254296.jpg',
#   './DataSet/images/apple_pie/3256198.jpg',
#   './DataSet/images/apple_pie/3273568.jpg',
#   './DataSet/images/apple_pie/3277458.jpg',
#   './DataSet/images/apple_pie/3277765.jpg',
#   './DataSet/images/apple_pie/3279836.jpg',
#   './DataSet/images/apple_pie/3280622.jpg',
#   './DataSet/images/apple_pie/3287607.jpg',
#   './DataSet/images/apple_pie/3297976.jpg',
#   './DataSet/images/apple_pie/330431.jpg',
#   './DataSet/images/apple_pie/3307686.jpg',
#   './DataSet/images/apple_pie/3313267.jpg',
#   './DataSet/images/apple_pie/3318370.jpg',
#   './DataSet/images/apple_pie/3324492.jpg',
#   './DataSet/images/apple_pie/3333030.jpg',
#   './DataSet/images/apple_pie/3335126.jpg',
#   './DataSet/images/apple_pie/333800.jpg',
#   './DataSet/images/apple_pie/3349423.jpg',
#   './DataSet/images/apple_pie/3358059.jpg',
#   './DataSet/images/apple_pie/3373840.jpg',
#   './DataSet/images/apple_pie/3375088.jpg',
#   './DataSet/images/apple_pie/3376635.jpg',
#   './DataSet/images/apple_pie/3392444.jpg',
#   './DataSet/images/apple_pie/339902.jpg',
#   './DataSet/images/apple_pie/339921.jpg',
#   './DataSet/images/apple_pie/3408912.jpg',
#   './DataSet/images/apple_pie/3410227.jpg',
#   './DataSet/images/apple_pie/3419799.jpg',
#   './DataSet/images/apple_pie/3420738.jpg',
#   './DataSet/images/apple_pie/3421349.jpg',
#   './DataSet/images/apple_pie/3427584.jpg',
#   './DataSet/images/apple_pie/3428446.jpg',
#   './DataSet/images/apple_pie/3438714.jpg',
#   './DataSet/images/apple_pie/3439550.jpg',
#   './DataSet/images/apple_pie/3440893.jpg',
#   './DataSet/images/apple_pie/3443899.jpg',
#   './DataSet/images/apple_pie/3448753.jpg',
#   './DataSet/images/apple_pie/3452805.jpg',
#   './DataSet/images/apple_pie/3461245.jpg',
#   './DataSet/images/apple_pie/3468573.jpg',
#   './DataSet/images/apple_pie/3478976.jpg',
#   './DataSet/images/apple_pie/3495444.jpg',
#   './DataSet/images/apple_pie/3501006.jpg',
#   './DataSet/images/apple_pie/3503020.jpg',
#   './DataSet/images/apple_pie/3503459.jpg',
#   './DataSet/images/apple_pie/3506848.jpg',
#   './DataSet/images/apple_pie/3508043.jpg',
#   './DataSet/images/apple_pie/3539782.jpg',
#   './DataSet/images/apple_pie/3545924.jpg',
#   './DataSet/images/apple_pie/3546563.jpg',
#   './DataSet/images/apple_pie/3549466.jpg',
#   './DataSet/images/apple_pie/3551588.jpg',
#   './DataSet/images/apple_pie/3563222.jpg',
#   './DataSet/images/apple_pie/3570483.jpg',
#   './DataSet/images/apple_pie/3574591.jpg',
#   './DataSet/images/apple_pie/3577845.jpg',
#   './DataSet/images/apple_pie/3586158.jpg',
#   './DataSet/images/apple_pie/3588721.jpg',
#   './DataSet/images/apple_pie/3589097.jpg',
#   './DataSet/images/apple_pie/3593810.jpg',
#   './DataSet/images/apple_pie/359419.jpg',
#   './DataSet/images/apple_pie/3594414.jpg',
#   './DataSet/images/apple_pie/3596143.jpg',
#   './DataSet/images/apple_pie/360406.jpg',
#   './DataSet/images/apple_pie/3613613.jpg',
#   './DataSet/images/apple_pie/3619289.jpg',
#   './DataSet/images/apple_pie/3634716.jpg',
#   './DataSet/images/apple_pie/3636185.jpg',
#   './DataSet/images/apple_pie/3637115.jpg',
#   './DataSet/images/apple_pie/3638370.jpg',
#   './DataSet/images/apple_pie/3641922.jpg',
#   './DataSet/images/apple_pie/3659123.jpg',
#   './DataSet/images/apple_pie/3664341.jpg',
#   './DataSet/images/apple_pie/3670548.jpg',
#   './DataSet/images/apple_pie/3670966.jpg',
#   './DataSet/images/apple_pie/3671998.jpg',
#   './DataSet/images/apple_pie/3683557.jpg',
#   './DataSet/images/apple_pie/3687109.jpg',
#   './DataSet/images/apple_pie/3696282.jpg',
#   './DataSet/images/apple_pie/3699587.jpg',
#   './DataSet/images/apple_pie/3708396.jpg',
#   './DataSet/images/apple_pie/3718506.jpg',
#   './DataSet/images/apple_pie/3723561.jpg',
#   './DataSet/images/apple_pie/3723836.jpg',
#   './DataSet/images/apple_pie/3728481.jpg',
#   './DataSet/images/apple_pie/3736084.jpg',
#   './DataSet/images/apple_pie/3748095.jpg',
#   './DataSet/images/apple_pie/3748402.jpg',
#   './DataSet/images/apple_pie/375297.jpg',
#   './DataSet/images/apple_pie/3760032.jpg',
#   './DataSet/images/apple_pie/3760078.jpg',
#   './DataSet/images/apple_pie/3770020.jpg',
#   './DataSet/images/apple_pie/3772671.jpg',
#   './DataSet/images/apple_pie/3783821.jpg',
#   './DataSet/images/apple_pie/3799430.jpg',
#   './DataSet/images/apple_pie/380024.jpg',
#   './DataSet/images/apple_pie/3805050.jpg',
#   './DataSet/images/apple_pie/3805347.jpg',
#   './DataSet/images/apple_pie/3814557.jpg',
#   './DataSet/images/apple_pie/3814952.jpg',
#   './DataSet/images/apple_pie/3815797.jpg',
#   './DataSet/images/apple_pie/3819511.jpg',
#   './DataSet/images/apple_pie/3829790.jpg',
#   './DataSet/images/apple_pie/3831510.jpg',
#   './DataSet/images/apple_pie/3831869.jpg',
#   './DataSet/images/apple_pie/3833386.jpg',
#   './DataSet/images/apple_pie/3833639.jpg',
#   './DataSet/images/apple_pie/3848012.jpg',
#   './DataSet/images/apple_pie/3869215.jpg',
#   './DataSet/images/apple_pie/3879031.jpg',
#   './DataSet/images/apple_pie/3882465.jpg',
#   './DataSet/images/apple_pie/3890705.jpg',
#   './DataSet/images/apple_pie/3897758.jpg',
#   './DataSet/images/apple_pie/3910026.jpg',
#   './DataSet/images/apple_pie/3913827.jpg',
#   './DataSet/images/apple_pie/3915887.jpg',
#   './DataSet/images/apple_pie/3917257.jpg',
#   './DataSet/images/apple_pie/392009.jpg',
#   './DataSet/images/apple_pie/395303.jpg',
#   './DataSet/images/apple_pie/395839.jpg',
#   './DataSet/images/apple_pie/405315.jpg',
#   './DataSet/images/apple_pie/407939.jpg',
#   './DataSet/images/apple_pie/412306.jpg',
#   './DataSet/images/apple_pie/412545.jpg',
#   './DataSet/images/apple_pie/420643.jpg',
#   './DataSet/images/apple_pie/420768.jpg',
#   './DataSet/images/apple_pie/421036.jpg',
#   './DataSet/images/apple_pie/424996.jpg',
#   './DataSet/images/apple_pie/437455.jpg',
#   './DataSet/images/apple_pie/456190.jpg',
#   './DataSet/images/apple_pie/456934.jpg',
#   './DataSet/images/apple_pie/471995.jpg',
#   './DataSet/images/apple_pie/481805.jpg',
#   './DataSet/images/apple_pie/483621.jpg',
#   './DataSet/images/apple_pie/484038.jpg',
#   './DataSet/images/apple_pie/488508.jpg',
#   './DataSet/images/apple_pie/490047.jpg',
#   './DataSet/images/apple_pie/498726.jpg',
#   './DataSet/images/apple_pie/502016.jpg',
#   './DataSet/images/apple_pie/505249.jpg',
#   './DataSet/images/apple_pie/523810.jpg',
#   './DataSet/images/apple_pie/524697.jpg',
#   './DataSet/images/apple_pie/532191.jpg',
#   './DataSet/images/apple_pie/532423.jpg',
#   './DataSet/images/apple_pie/532972.jpg',
#   './DataSet/images/apple_pie/535444.jpg',
#   './DataSet/images/apple_pie/543253.jpg',
#   './DataSet/images/apple_pie/544151.jpg',
#   './DataSet/images/apple_pie/547961.jpg',
#   './DataSet/images/apple_pie/551535.jpg',
#   './DataSet/images/apple_pie/559953.jpg',
#   './DataSet/images/apple_pie/562659.jpg',
#   './DataSet/images/apple_pie/589712.jpg',
#   './DataSet/images/apple_pie/591398.jpg',
#   './DataSet/images/apple_pie/594677.jpg',
#   './DataSet/images/apple_pie/597533.jpg',
#   './DataSet/images/apple_pie/603113.jpg',
#   './DataSet/images/apple_pie/604375.jpg',
#   './DataSet/images/apple_pie/605117.jpg',
#   './DataSet/images/apple_pie/624715.jpg',
#   './DataSet/images/apple_pie/631412.jpg',
#   './DataSet/images/apple_pie/631445.jpg',
#   './DataSet/images/apple_pie/63651.jpg',
#   './DataSet/images/apple_pie/644109.jpg',
#   './DataSet/images/apple_pie/647043.jpg',
#   './DataSet/images/apple_pie/64846.jpg',
#   './DataSet/images/apple_pie/649621.jpg',
#   './DataSet/images/apple_pie/650815.jpg',
#   './DataSet/images/apple_pie/653135.jpg',
#   './DataSet/images/apple_pie/656340.jpg',
#   './DataSet/images/apple_pie/657618.jpg',
#   './DataSet/images/apple_pie/668603.jpg',
#   './DataSet/images/apple_pie/671980.jpg',
#   './DataSet/images/apple_pie/672196.jpg',
#   './DataSet/images/apple_pie/672263.jpg',
#   './DataSet/images/apple_pie/67826.jpg',
#   './DataSet/images/apple_pie/678482.jpg',
#   './DataSet/images/apple_pie/68383.jpg',
#   './DataSet/images/apple_pie/687503.jpg',
#   './DataSet/images/apple_pie/687506.jpg',
#   './DataSet/images/apple_pie/692211.jpg',
#   './DataSet/images/apple_pie/695587.jpg',
#   './DataSet/images/apple_pie/696914.jpg',
#   './DataSet/images/apple_pie/698341.jpg',
#   './DataSet/images/apple_pie/715180.jpg',
#   './DataSet/images/apple_pie/722783.jpg',
#   './DataSet/images/apple_pie/727412.jpg',
#   './DataSet/images/apple_pie/739410.jpg',
#   './DataSet/images/apple_pie/739615.jpg',
#   './DataSet/images/apple_pie/742789.jpg',
#   './DataSet/images/apple_pie/750073.jpg',
#   './DataSet/images/apple_pie/755031.jpg',
#   './DataSet/images/apple_pie/767102.jpg',
#   './DataSet/images/apple_pie/767395.jpg',
#   './DataSet/images/apple_pie/769522.jpg',
#   './DataSet/images/apple_pie/770439.jpg',
#   './DataSet/images/apple_pie/771595.jpg',
#   './DataSet/images/apple_pie/78081.jpg',
#   './DataSet/images/apple_pie/790787.jpg',
#   './DataSet/images/apple_pie/793078.jpg',
#   './DataSet/images/apple_pie/794735.jpg',
#   './DataSet/images/apple_pie/80734.jpg',
#   './DataSet/images/apple_pie/80735.jpg',
#   './DataSet/images/apple_pie/813881.jpg',
#   './DataSet/images/apple_pie/817073.jpg',
#   './DataSet/images/apple_pie/817552.jpg',
#   './DataSet/images/apple_pie/822817.jpg',
#   './DataSet/images/apple_pie/825589.jpg',
#   './DataSet/images/apple_pie/833369.jpg',
#   './DataSet/images/apple_pie/839808.jpg',
#   './DataSet/images/apple_pie/839845.jpg',
#   './DataSet/images/apple_pie/842012.jpg',
#   './DataSet/images/apple_pie/854595.jpg',
#   './DataSet/images/apple_pie/85857.jpg',
#   './DataSet/images/apple_pie/858876.jpg',
#   './DataSet/images/apple_pie/860651.jpg',
#   './DataSet/images/apple_pie/865073.jpg',
#   './DataSet/images/apple_pie/871917.jpg',
#   './DataSet/images/apple_pie/873371.jpg',
#   './DataSet/images/apple_pie/874809.jpg',
#   './DataSet/images/apple_pie/881628.jpg',
#   './DataSet/images/apple_pie/886518.jpg',
#   './DataSet/images/apple_pie/89035.jpg',
#   './DataSet/images/apple_pie/892425.jpg',
#   './DataSet/images/apple_pie/902277.jpg',
#   './DataSet/images/apple_pie/909196.jpg',
#   './DataSet/images/apple_pie/910097.jpg',
#   './DataSet/images/apple_pie/910333.jpg',
#   './DataSet/images/apple_pie/913161.jpg',
#   './DataSet/images/apple_pie/925525.jpg',
#   './DataSet/images/apple_pie/934113.jpg',
#   './DataSet/images/apple_pie/934503.jpg',
#   './DataSet/images/apple_pie/936189.jpg',
#   './DataSet/images/apple_pie/937118.jpg',
#   './DataSet/images/apple_pie/939246.jpg',
#   './DataSet/images/apple_pie/939768.jpg',
#   './DataSet/images/apple_pie/939827.jpg',
#   './DataSet/images/apple_pie/946403.jpg',
#   './DataSet/images/apple_pie/947689.jpg',
#   './DataSet/images/apple_pie/954830.jpg',
#   './DataSet/images/apple_pie/957090.jpg',
#   './DataSet/images/apple_pie/959388.jpg',
#   './DataSet/images/apple_pie/959678.jpg',
#   './DataSet/images/apple_pie/960233.jpg',
#   './DataSet/images/apple_pie/960669.jpg',
#   './DataSet/images/apple_pie/962315.jpg',
#   './DataSet/images/apple_pie/966595.jpg',
#   './DataSet/images/apple_pie/973088.jpg',
#   './DataSet/images/apple_pie/973428.jpg',
#   './DataSet/images/apple_pie/98352.jpg',
#   './DataSet/images/apple_pie/98449.jpg',
#   './DataSet/images/apple_pie/987860.jpg',
#   './DataSet/images/apple_pie/997124.jpg',
#   './DataSet/images/baby_back_ribs/1005293.jpg',
#   './DataSet/images/baby_back_ribs/1007102.jpg',
#   './DataSet/images/baby_back_ribs/1007272.jpg',
#   './DataSet/images/baby_back_ribs/1008749.jpg',
#   './DataSet/images/baby_back_ribs/1009028.jpg',
#   './DataSet/images/baby_back_ribs/1031072.jpg',
#   './DataSet/images/baby_back_ribs/1031112.jpg',
#   './DataSet/images/baby_back_ribs/1034506.jpg',
#   './DataSet/images/baby_back_ribs/1062026.jpg',
#   './DataSet/images/baby_back_ribs/1062097.jpg',
#   './DataSet/images/baby_back_ribs/1070017.jpg',
#   './DataSet/images/baby_back_ribs/1073370.jpg',
#   './DataSet/images/baby_back_ribs/1078506.jpg',
#   './DataSet/images/baby_back_ribs/1078518.jpg',
#   './DataSet/images/baby_back_ribs/1079522.jpg',
#   './DataSet/images/baby_back_ribs/1081312.jpg',
#   './DataSet/images/baby_back_ribs/108211.jpg',
#   './DataSet/images/baby_back_ribs/1083903.jpg',
#   './DataSet/images/baby_back_ribs/1084769.jpg',
#   './DataSet/images/baby_back_ribs/1085337.jpg',
#   './DataSet/images/baby_back_ribs/109256.jpg',
#   './DataSet/images/baby_back_ribs/1099273.jpg',
#   './DataSet/images/baby_back_ribs/1106965.jpg',
#   './DataSet/images/baby_back_ribs/112032.jpg',
#   './DataSet/images/baby_back_ribs/1128175.jpg',
#   './DataSet/images/baby_back_ribs/1128504.jpg',
#   './DataSet/images/baby_back_ribs/1131511.jpg',
#   './DataSet/images/baby_back_ribs/1131795.jpg',
#   './DataSet/images/baby_back_ribs/1140712.jpg',
#   './DataSet/images/baby_back_ribs/1148389.jpg',
#   './DataSet/images/baby_back_ribs/1153312.jpg',
#   './DataSet/images/baby_back_ribs/1153453.jpg',
#   './DataSet/images/baby_back_ribs/1157308.jpg',
#   './DataSet/images/baby_back_ribs/1169971.jpg',
#   './DataSet/images/baby_back_ribs/1174148.jpg',
#   './DataSet/images/baby_back_ribs/1181199.jpg',
#   './DataSet/images/baby_back_ribs/1181776.jpg',
#   './DataSet/images/baby_back_ribs/1185974.jpg',
#   './DataSet/images/baby_back_ribs/1189974.jpg',
#   './DataSet/images/baby_back_ribs/119255.jpg',
#   './DataSet/images/baby_back_ribs/1192660.jpg',
#   './DataSet/images/baby_back_ribs/119355.jpg',
#   './DataSet/images/baby_back_ribs/1193861.jpg',
#   './DataSet/images/baby_back_ribs/1199055.jpg',
#   './DataSet/images/baby_back_ribs/1201223.jpg',
#   './DataSet/images/baby_back_ribs/1202936.jpg',
#   './DataSet/images/baby_back_ribs/1211748.jpg',
#   './DataSet/images/baby_back_ribs/1224799.jpg',
#   './DataSet/images/baby_back_ribs/1229921.jpg',
#   './DataSet/images/baby_back_ribs/1239239.jpg',
#   './DataSet/images/baby_back_ribs/1239248.jpg',
#   './DataSet/images/baby_back_ribs/1240920.jpg',
#   './DataSet/images/baby_back_ribs/1241704.jpg',
#   './DataSet/images/baby_back_ribs/1252252.jpg',
#   './DataSet/images/baby_back_ribs/1258771.jpg',
#   './DataSet/images/baby_back_ribs/1259396.jpg',
#   './DataSet/images/baby_back_ribs/1262560.jpg',
#   './DataSet/images/baby_back_ribs/1267432.jpg',
#   './DataSet/images/baby_back_ribs/1285755.jpg',
#   './DataSet/images/baby_back_ribs/1288297.jpg',
#   './DataSet/images/baby_back_ribs/1291979.jpg',
#   './DataSet/images/baby_back_ribs/1298956.jpg',
#   './DataSet/images/baby_back_ribs/1299678.jpg',
#   './DataSet/images/baby_back_ribs/1299686.jpg',
#   './DataSet/images/baby_back_ribs/1300306.jpg',
#   './DataSet/images/baby_back_ribs/1315753.jpg',
#   './DataSet/images/baby_back_ribs/1316579.jpg',
#   './DataSet/images/baby_back_ribs/1320872.jpg',
#   './DataSet/images/baby_back_ribs/1324788.jpg',
#   './DataSet/images/baby_back_ribs/1325806.jpg',
#   './DataSet/images/baby_back_ribs/1334446.jpg',
#   './DataSet/images/baby_back_ribs/1341092.jpg',
#   './DataSet/images/baby_back_ribs/1342514.jpg',
#   './DataSet/images/baby_back_ribs/1343043.jpg',
#   './DataSet/images/baby_back_ribs/1346675.jpg',
#   './DataSet/images/baby_back_ribs/1346686.jpg',
#   './DataSet/images/baby_back_ribs/1353805.jpg',
#   './DataSet/images/baby_back_ribs/1362359.jpg',
#   './DataSet/images/baby_back_ribs/1367931.jpg',
#   './DataSet/images/baby_back_ribs/1371630.jpg',
#   './DataSet/images/baby_back_ribs/1373674.jpg',
#   './DataSet/images/baby_back_ribs/137626.jpg',
#   './DataSet/images/baby_back_ribs/1377033.jpg',
#   './DataSet/images/baby_back_ribs/1384024.jpg',
#   './DataSet/images/baby_back_ribs/1386077.jpg',
#   './DataSet/images/baby_back_ribs/1392004.jpg',
#   './DataSet/images/baby_back_ribs/1395170.jpg',
#   './DataSet/images/baby_back_ribs/1395570.jpg',
#   './DataSet/images/baby_back_ribs/140335.jpg',
#   './DataSet/images/baby_back_ribs/1416598.jpg',
#   './DataSet/images/baby_back_ribs/1421473.jpg',
#   './DataSet/images/baby_back_ribs/1429122.jpg',
#   './DataSet/images/baby_back_ribs/1436844.jpg',
#   './DataSet/images/baby_back_ribs/1438054.jpg',
#   './DataSet/images/baby_back_ribs/1441141.jpg',
#   './DataSet/images/baby_back_ribs/1446793.jpg',
#   './DataSet/images/baby_back_ribs/1459848.jpg',
#   './DataSet/images/baby_back_ribs/1464660.jpg',
#   './DataSet/images/baby_back_ribs/1475641.jpg',
#   './DataSet/images/baby_back_ribs/1478335.jpg',
#   './DataSet/images/baby_back_ribs/1480327.jpg',
#   './DataSet/images/baby_back_ribs/148270.jpg',
#   './DataSet/images/baby_back_ribs/1483871.jpg',
#   './DataSet/images/baby_back_ribs/1485747.jpg',
#   './DataSet/images/baby_back_ribs/1494720.jpg',
#   './DataSet/images/baby_back_ribs/1495433.jpg',
#   './DataSet/images/baby_back_ribs/1499720.jpg',
#   './DataSet/images/baby_back_ribs/1503924.jpg',
#   './DataSet/images/baby_back_ribs/1505833.jpg',
#   './DataSet/images/baby_back_ribs/1520322.jpg',
#   './DataSet/images/baby_back_ribs/1520658.jpg',
#   './DataSet/images/baby_back_ribs/1525686.jpg',
#   './DataSet/images/baby_back_ribs/1533018.jpg',
#   './DataSet/images/baby_back_ribs/1537031.jpg',
#   './DataSet/images/baby_back_ribs/1537034.jpg',
#   './DataSet/images/baby_back_ribs/1537116.jpg',
#   './DataSet/images/baby_back_ribs/153883.jpg',
#   './DataSet/images/baby_back_ribs/1550594.jpg',
#   './DataSet/images/baby_back_ribs/1552922.jpg',
#   './DataSet/images/baby_back_ribs/155690.jpg',
#   './DataSet/images/baby_back_ribs/1558128.jpg',
#   './DataSet/images/baby_back_ribs/1558275.jpg',
#   './DataSet/images/baby_back_ribs/1559619.jpg',
#   './DataSet/images/baby_back_ribs/1563530.jpg',
#   './DataSet/images/baby_back_ribs/156707.jpg',
#   './DataSet/images/baby_back_ribs/1567658.jpg',
#   './DataSet/images/baby_back_ribs/1571645.jpg',
#   './DataSet/images/baby_back_ribs/1571940.jpg',
#   './DataSet/images/baby_back_ribs/1576431.jpg',
#   './DataSet/images/baby_back_ribs/1576772.jpg',
#   './DataSet/images/baby_back_ribs/1577255.jpg',
#   './DataSet/images/baby_back_ribs/1582932.jpg',
#   './DataSet/images/baby_back_ribs/1587924.jpg',
#   './DataSet/images/baby_back_ribs/1588562.jpg',
#   './DataSet/images/baby_back_ribs/1593944.jpg',
#   './DataSet/images/baby_back_ribs/1596759.jpg',
#   './DataSet/images/baby_back_ribs/1597189.jpg',
#   './DataSet/images/baby_back_ribs/1608850.jpg',
#   './DataSet/images/baby_back_ribs/1610050.jpg',
#   './DataSet/images/baby_back_ribs/1615155.jpg',
#   './DataSet/images/baby_back_ribs/1619479.jpg',
#   './DataSet/images/baby_back_ribs/1620823.jpg',
#   './DataSet/images/baby_back_ribs/1621773.jpg',
#   './DataSet/images/baby_back_ribs/1622288.jpg',
#   './DataSet/images/baby_back_ribs/1622962.jpg',
#   './DataSet/images/baby_back_ribs/1623979.jpg',
#   './DataSet/images/baby_back_ribs/1632377.jpg',
#   './DataSet/images/baby_back_ribs/1635329.jpg',
#   './DataSet/images/baby_back_ribs/16366.jpg',
#   './DataSet/images/baby_back_ribs/1640728.jpg',
#   './DataSet/images/baby_back_ribs/1643275.jpg',
#   './DataSet/images/baby_back_ribs/1644147.jpg',
#   './DataSet/images/baby_back_ribs/1651771.jpg',
#   './DataSet/images/baby_back_ribs/1656357.jpg',
#   './DataSet/images/baby_back_ribs/1675917.jpg',
#   './DataSet/images/baby_back_ribs/1676135.jpg',
#   './DataSet/images/baby_back_ribs/1676905.jpg',
#   './DataSet/images/baby_back_ribs/1676906.jpg',
#   './DataSet/images/baby_back_ribs/1677624.jpg',
#   './DataSet/images/baby_back_ribs/1679824.jpg',
#   './DataSet/images/baby_back_ribs/167990.jpg',
#   './DataSet/images/baby_back_ribs/1681286.jpg',
#   './DataSet/images/baby_back_ribs/1684592.jpg',
#   './DataSet/images/baby_back_ribs/1686741.jpg',
#   './DataSet/images/baby_back_ribs/1688043.jpg',
#   './DataSet/images/baby_back_ribs/1688240.jpg',
#   './DataSet/images/baby_back_ribs/1695610.jpg',
#   './DataSet/images/baby_back_ribs/1699771.jpg',
#   './DataSet/images/baby_back_ribs/1709704.jpg',
#   './DataSet/images/baby_back_ribs/1711775.jpg',
#   './DataSet/images/baby_back_ribs/1716566.jpg',
#   './DataSet/images/baby_back_ribs/1718129.jpg',
#   './DataSet/images/baby_back_ribs/1726178.jpg',
#   './DataSet/images/baby_back_ribs/1729685.jpg',
#   './DataSet/images/baby_back_ribs/1730203.jpg',
#   './DataSet/images/baby_back_ribs/1737370.jpg',
#   './DataSet/images/baby_back_ribs/1740768.jpg',
#   './DataSet/images/baby_back_ribs/1745601.jpg',
#   './DataSet/images/baby_back_ribs/1749425.jpg',
#   './DataSet/images/baby_back_ribs/1752664.jpg',
#   './DataSet/images/baby_back_ribs/1757611.jpg',
#   './DataSet/images/baby_back_ribs/1766448.jpg',
#   './DataSet/images/baby_back_ribs/1770157.jpg',
#   './DataSet/images/baby_back_ribs/1772427.jpg',
#   './DataSet/images/baby_back_ribs/1774172.jpg',
#   './DataSet/images/baby_back_ribs/1775388.jpg',
#   './DataSet/images/baby_back_ribs/1794902.jpg',
#   './DataSet/images/baby_back_ribs/1804408.jpg',
#   './DataSet/images/baby_back_ribs/1804706.jpg',
#   './DataSet/images/baby_back_ribs/1804724.jpg',
#   './DataSet/images/baby_back_ribs/1806940.jpg',
#   './DataSet/images/baby_back_ribs/1807563.jpg',
#   './DataSet/images/baby_back_ribs/1814986.jpg',
#   './DataSet/images/baby_back_ribs/1819387.jpg',
#   './DataSet/images/baby_back_ribs/1821315.jpg',
#   './DataSet/images/baby_back_ribs/1829271.jpg',
#   './DataSet/images/baby_back_ribs/1832939.jpg',
#   './DataSet/images/baby_back_ribs/1838405.jpg',
#   './DataSet/images/baby_back_ribs/1839467.jpg',
#   './DataSet/images/baby_back_ribs/1840540.jpg',
#   './DataSet/images/baby_back_ribs/1841024.jpg',
#   './DataSet/images/baby_back_ribs/1845573.jpg',
#   './DataSet/images/baby_back_ribs/184567.jpg',
#   './DataSet/images/baby_back_ribs/1848417.jpg',
#   './DataSet/images/baby_back_ribs/1858401.jpg',
#   './DataSet/images/baby_back_ribs/1862790.jpg',
#   './DataSet/images/baby_back_ribs/1875652.jpg',
#   './DataSet/images/baby_back_ribs/1876802.jpg',
#   './DataSet/images/baby_back_ribs/1878380.jpg',
#   './DataSet/images/baby_back_ribs/1879515.jpg',
#   './DataSet/images/baby_back_ribs/1880868.jpg',
#   './DataSet/images/baby_back_ribs/1887058.jpg',
#   './DataSet/images/baby_back_ribs/188943.jpg',
#   './DataSet/images/baby_back_ribs/189367.jpg',
#   './DataSet/images/baby_back_ribs/1895338.jpg',
#   './DataSet/images/baby_back_ribs/189917.jpg',
#   './DataSet/images/baby_back_ribs/1902615.jpg',
#   './DataSet/images/baby_back_ribs/1907959.jpg',
#   './DataSet/images/baby_back_ribs/1910700.jpg',
#   './DataSet/images/baby_back_ribs/1917025.jpg',
#   './DataSet/images/baby_back_ribs/1921931.jpg',
#   './DataSet/images/baby_back_ribs/1928477.jpg',
#   './DataSet/images/baby_back_ribs/1929872.jpg',
#   './DataSet/images/baby_back_ribs/1931741.jpg',
#   './DataSet/images/baby_back_ribs/1934757.jpg',
#   './DataSet/images/baby_back_ribs/1934927.jpg',
#   './DataSet/images/baby_back_ribs/1936442.jpg',
#   './DataSet/images/baby_back_ribs/1941026.jpg',
#   './DataSet/images/baby_back_ribs/1941557.jpg',
#   './DataSet/images/baby_back_ribs/1943575.jpg',
#   './DataSet/images/baby_back_ribs/1951972.jpg',
#   './DataSet/images/baby_back_ribs/1957350.jpg',
#   './DataSet/images/baby_back_ribs/1959961.jpg',
#   './DataSet/images/baby_back_ribs/1966568.jpg',
#   './DataSet/images/baby_back_ribs/1970515.jpg',
#   './DataSet/images/baby_back_ribs/1971262.jpg',
#   './DataSet/images/baby_back_ribs/1972389.jpg',
#   './DataSet/images/baby_back_ribs/1975684.jpg',
#   './DataSet/images/baby_back_ribs/1976124.jpg',
#   './DataSet/images/baby_back_ribs/1976409.jpg',
#   './DataSet/images/baby_back_ribs/1978213.jpg',
#   './DataSet/images/baby_back_ribs/1986342.jpg',
#   './DataSet/images/baby_back_ribs/1987216.jpg',
#   './DataSet/images/baby_back_ribs/1998638.jpg',
#   './DataSet/images/baby_back_ribs/2009356.jpg',
#   './DataSet/images/baby_back_ribs/2010205.jpg',
#   './DataSet/images/baby_back_ribs/2013073.jpg',
#   './DataSet/images/baby_back_ribs/2018808.jpg',
#   './DataSet/images/baby_back_ribs/2022932.jpg',
#   './DataSet/images/baby_back_ribs/2023500.jpg',
#   ...],
#  'label': ['apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'apple_pie',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   'baby_back_ribs',
#   ...]}

# %%
train_dataset = Dataset.from_dict(train)
test_dataset = Dataset.from_dict(test)
dataset_dict = DatasetDict({"train": train_dataset, "test": test_dataset})
train_split = dataset_dict["train"]
test_split = dataset_dict["test"]
dataset_dict
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 75750
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 25250
#     })
# })

# %%
ex = data['train'][400]
ex
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=384x512 at 0x28596D1EAC0>,
#  'label': 94}

# %%
image = ex['image']
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=384x512 at 0x28596D1EAC0>

# %%
labels = data['train'].features['label']
labels
# Out:
# ClassLabel(names=['apple_pie', 'baby_back_ribs', 'baklava', 'beef_carpaccio', 'beef_tartare', 'beet_salad', 'beignets', 'bibimbap', 'bread_pudding', 'breakfast_burrito', 'bruschetta', 'caesar_salad', 'cannoli', 'caprese_salad', 'carrot_cake', 'ceviche', 'cheese_plate', 'cheesecake', 'chicken_curry', 'chicken_quesadilla', 'chicken_wings', 'chocolate_cake', 'chocolate_mousse', 'churros', 'clam_chowder', 'club_sandwich', 'crab_cakes', 'creme_brulee', 'croque_madame', 'cup_cakes', 'deviled_eggs', 'donuts', 'dumplings', 'edamame', 'eggs_benedict', 'escargots', 'falafel', 'filet_mignon', 'fish_and_chips', 'foie_gras', 'french_fries', 'french_onion_soup', 'french_toast', 'fried_calamari', 'fried_rice', 'frozen_yogurt', 'garlic_bread', 'gnocchi', 'greek_salad', 'grilled_cheese_sandwich', 'grilled_salmon', 'guacamole', 'gyoza', 'hamburger', 'hot_and_sour_soup', 'hot_dog', 'huevos_rancheros', 'hummus', 'ice_cream', 'lasagna', 'lobster_bisque', 'lobster_roll_sandwich', 'macaroni_and_cheese', 'macarons', 'miso_soup', 'mussels', 'nachos', 'omelette', 'onion_rings', 'oysters', 'pad_thai', 'paella', 'pancakes', 'panna_cotta', 'peking_duck', 'pho', 'pizza', 'pork_chop', 'poutine', 'prime_rib', 'pulled_pork_sandwich', 'ramen', 'ravioli', 'red_velvet_cake', 'risotto', 'samosa', 'sashimi', 'scallops', 'seaweed_salad', 'shrimp_and_grits', 'spaghetti_bolognese', 'spaghetti_carbonara', 'spring_rolls', 'steak', 'strawberry_shortcake', 'sushi', 'tacos', 'takoyaki', 'tiramisu', 'tuna_tartare', 'waffles'], id=None)

# %%
labels.int2str(ex['label'])
# Out:
# 'strawberry_shortcake'

# %%
import os
from huggingface_hub import notebook_login

notebook_login()
#os.environ['HF_HOME'] = '{"access_token": "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"}
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from transformers import ViTFeatureExtractor

model_name_or_path = 'google/vit-base-patch16-224-in21k'
feature_extractor = ViTFeatureExtractor.from_pretrained(model_name_or_path)

# %%
from torchvision.transforms import (
    CenterCrop,
    Compose,
    Normalize,
    RandomHorizontalFlip,
    RandomResizedCrop,
    Resize,
    ToTensor,
)

normalize = Normalize(mean=feature_extractor.image_mean, std=feature_extractor.image_std)
train_transforms = Compose(
        [
            RandomResizedCrop(feature_extractor.size),
            RandomHorizontalFlip(),
            ToTensor(),
            normalize,
        ]
    )
val_transforms = Compose(
        [
            Resize((224,224)),
            CenterCrop(feature_extractor.size),
            ToTensor(),
            normalize,
        ]
    )

def preprocess_train(example_batch):
    """Apply train_transforms across a batch."""
    example_batch["pixel_values"] = [
        train_transforms(image.convert("RGB")) for image in example_batch["image"]
    ]
    return example_batch

def preprocess_val(example_batch):
    """Apply val_transforms across a batch."""
    example_batch["pixel_values"] = [val_transforms(image.convert("RGB")) for image in example_batch["image"]]
    return example_batch

# %%
# split up training into training + validation
train_ds = data['train']
val_ds = data['test']

# %%
print(train_ds)
test = train_ds.set_transform(preprocess_train)
val_ds.set_transform(preprocess_val)
print(test)
# Out:
# Dataset({
#     features: ['image', 'label'],
#     num_rows: 85850
# })
# None

# %%
from transformers import ViTForImageClassification
model_name_or_path = 'google/vit-base-patch16-224-in21k'
model = ViTForImageClassification.from_pretrained(
    model_name_or_path, 
    num_labels=len(labels.names),
    id2label={str(i): c for i, c in enumerate(labels.names)},
    label2id={c: str(i) for i, c in enumerate(labels.names)}
)
# Out:
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    'Food-Recognition',
  per_device_train_batch_size=16,
  evaluation_strategy="steps",
  num_train_epochs=4,
  save_steps=100,
  eval_steps=100,
  logging_steps=10,
  learning_rate=2e-4,
  save_total_limit=2,
  remove_unused_columns=False,
  push_to_hub=True,
  report_to='tensorboard',
  load_best_model_at_end=True,
  hub_strategy="end"
)

# %%
import numpy as np

# the compute_metrics function takes a Named Tuple as input:
# predictions, which are the logits of the model as Numpy arrays,
# and label_ids, which are the ground-truth labels as Numpy arrays.
def compute_metrics(eval_pred):
    """Computes accuracy on a batch of predictions"""
    predictions = np.argmax(eval_pred.predictions, axis=1)
    return metric.compute(predictions=predictions, references=eval_pred.label_ids)

# %%
import torch

def collate_fn(batch):
    return {
        'pixel_values': torch.stack([x['pixel_values'] for x in batch]),
        'labels': torch.tensor([x['label'] for x in batch])
    }

# %%
from transformers import Trainer
trainer = Trainer(
    model,
    training_args,
    train_dataset=train_ds,
    eval_dataset=val_ds,
    tokenizer=feature_extractor,
    compute_metrics=compute_metrics,
    data_collator=collate_fn,
)

# %%
train_results = trainer.train()
# rest is optional but nice to have
trainer.save_model()
trainer.log_metrics("train", train_results.metrics)
trainer.save_metrics("train", train_results.metrics)
trainer.save_state()
# Out:
#   0%|          | 0/21464 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Temp\ipykernel_10312\1071311064.py in <module>
# ----> 1 train_results = trainer.train()
#       2 # rest is optional but nice to have
#       3 trainer.save_model()
#       4 trainer.log_metrics("train", train_results.metrics)
#       5 trainer.save_metrics("train", train_results.metrics)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\transformers\trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1544                 # Disable progress bars when uploading models during checkpoints to avoid polluting stdout
#    1545                 hf_hub_utils.disable_progress_bars()
# -> 1546                 return inner_training_loop(
#    1547                     args=args,
#    1548                     resume_from_checkpoint=resume_from_checkpoint,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\transformers\trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1836
#    1837             step = -1
# -> 1838             for step, inputs in enumerate(epoch_iterator):
#    1839                 total_batched_samples += 1
#    1840                 if rng_to_sync:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\accelerate\data_loader.py in __iter__(self)
#     446         # We iterate one batch ahead to check when we are at the end
#     447         try:
# --> 448             current_batch = next(dataloader_iter)
#     449         except StopIteration:
#     450             yield
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     628                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629                 self._reset()  # type: ignore[call-arg]
# --> 630             data = self._next_data()
#     631             self._num_yielded += 1
#     632             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     672     def _next_data(self):
#     673         index = self._next_index()  # may raise StopIteration
# --> 674         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675         if self._pin_memory:
#     676             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      47         if self.auto_collation:
#      48             if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
#      51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\datasets\arrow_dataset.py in __getitems__(self, keys)
#    2797     def __getitems__(self, keys: List) -> List:
#    2798         """Can be used to get a batch using a list of integers indices."""
# -> 2799         batch = self.__getitem__(keys)
#    2800         n_examples = len(batch[next(iter(batch))])
#    2801         return [{col: array[i] for col, array in batch.items()} for i in range(n_examples)]
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\datasets\arrow_dataset.py in __getitem__(self, key)
#    2793     def __getitem__(self, key):  # noqa: F811
#    2794         """Can be used to index columns (by string names) or rows (by integer index or iterable of indices or bools)."""
# -> 2795         return self._getitem(key)
#    2796
#    2797     def __getitems__(self, keys: List) -> List:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\datasets\arrow_dataset.py in _getitem(self, key, **kwargs)
#    2778         formatter = get_formatter(format_type, features=self._info.features, **format_kwargs)
#    2779         pa_subtable = query_table(self._data, key, indices=self._indices if self._indices is not None else None)
# -> 2780         formatted_output = format_table(
#    2781             pa_subtable, key, formatter=formatter, format_columns=format_columns, output_all_columns=output_all_columns
#    2782         )
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\datasets\formatting\formatting.py in format_table(table, key, formatter, format_columns, output_all_columns)
#     627     python_formatter = PythonFormatter(features=formatter.features)
#     628     if format_columns is None:
# --> 629         return formatter(pa_table, query_type=query_type)
#     630     elif query_type == "column":
#     631         if key in format_columns:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\datasets\formatting\formatting.py in __call__(self, pa_table, query_type)
#     398             return self.format_column(pa_table)
#     399         elif query_type == "batch":
# --> 400             return self.format_batch(pa_table)
#     401
#     402     def format_row(self, pa_table: pa.Table) -> RowFormat:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\datasets\formatting\formatting.py in format_batch(self, pa_table)
#     513         batch = self.python_arrow_extractor().extract_batch(pa_table)
#     514         batch = self.python_features_decoder.decode_batch(batch)
# --> 515         return self.transform(batch)
#     516
#     517
#
# D:\Temp\ipykernel_10312\3216198760.py in preprocess_train(example_batch)
#      29 def preprocess_train(example_batch):
#      30     """Apply train_transforms across a batch."""
# ---> 31     example_batch["pixel_values"] = [
#      32         train_transforms(image.convert("RGB")) for image in example_batch["image"]
#      33     ]
#
# D:\Temp\ipykernel_10312\3216198760.py in <listcomp>(.0)
#      30     """Apply train_transforms across a batch."""
#      31     example_batch["pixel_values"] = [
# ---> 32         train_transforms(image.convert("RGB")) for image in example_batch["image"]
#      33     ]
#      34     return example_batch
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torchvision\transforms\transforms.py in __call__(self, img)
#      93     def __call__(self, img):
#      94         for t in self.transforms:
# ---> 95             img = t(img)
#      96         return img
#      97
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\nn\modules\module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torchvision\transforms\transforms.py in forward(self, img)
#     978         """
#     979         i, j, h, w = self.get_params(img, self.scale, self.ratio)
# --> 980         return F.resized_crop(img, i, j, h, w, self.size, self.interpolation, antialias=self.antialias)
#     981
#     982     def __repr__(self) -> str:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torchvision\transforms\functional.py in resized_crop(img, top, left, height, width, size, interpolation, antialias)
#     661         _log_api_usage_once(resized_crop)
#     662     img = crop(img, top, left, height, width)
# --> 663     img = resize(img, size, interpolation, antialias=antialias)
#     664     return img
#     665
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torchvision\transforms\functional.py in resize(img, size, interpolation, max_size, antialias)
#     477     if isinstance(size, int):
#     478         size = [size]
# --> 479     output_size = _compute_resized_output_size((image_height, image_width), size, max_size)
#     480
#     481     if [image_height, image_width] == output_size:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torchvision\transforms\functional.py in _compute_resized_output_size(image_size, size, max_size)
#     385         new_w, new_h = (new_short, new_long) if w <= h else (new_long, new_short)
#     386     else:  # specified both h and w
# --> 387         new_w, new_h = size[1], size[0]
#     388     return [new_h, new_w]
#     389
#
# KeyError: 1
